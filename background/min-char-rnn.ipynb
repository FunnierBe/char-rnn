# %% [markdown]
# # Minimal character-level, ultra-basic plain vanilla RNN model
#
# This notebook is actually just an annotated, updated-for-Python3 fork of [ONE of several explanatory gists in Torch neural networks, RNN, LSTM](https://gist.github.com/karpathy), specifically [**min-char-rnn.py](https://gist.github.com/karpathy/d4dee566867f8291f086) which worked with Python2 and was written several years ago by [Andrej Karpathy](https://gist.github.com/karpathy) [Twitter@karpathy](https://twitter.com/karpathy).
#
# You will probably want to play with pararmeters or change things in this code or the **input.txt* file to see how it works. Others, like [Jy-Yoon](https://github.com/JY-Yoon) or [Nikhil Barhate](https://github.com/nikhilbarhate99) have worked thru the [original **min-char-rnn.py**](https://gist.github.com/karpathy/d4dee566867f8291f086) and shared their own take of Python3-updated gist of [an RNN implementation using Numpy](https://github.com/JY-Yoon/RNN-Implementation-using-NumPy) or [Char RNN PyTorch](https://github.com/nikhilbarhate99/Char-RNN-PyTorch), respectively. There are obviously plenty more of these out there -- maybe we can't look at them all but it's worth looking at more of these to see how they differ.
#
# Naturally, the [BSD license](https://en.wikipedia.org/wiki/BSD_licenses) of the [original **min-char-rnn.py**](https://gist.github.com/karpathy/d4dee566867f8291f086)  would carry over to this particular .ipynb notebook given the notebook's derivation, but [the choice of that license](https://choosealicense.com/) does not apply to the other files in this repository.

# %%
# This .ipynb notebook was developed using Python 3.9.14 and Numpy 1.23.5; obviously, your milege could vary with other versions.

import numpy as np

# %% [markdown]
# #### NumPy needs to be installed -- could we do this without NumPy or use a different library?
#
# That might take some re-invention of the wheel ... we can look at the dependencies; what will we need Numpy for ... and then we might wonder why NumPy is not built-in or included with every Python installation?  That could be a question worth pondering if we are doing trillions of ephemeral installation of Python or Jupyter Notebooks.
#
# We will eventually need NumPy for the following:
#
# * first thing
# * second thing
# * third thing
#
# We don't need NumPy right off the bat ...for [`open()`](https://docs.python.org/3/library/functions.html#open), which is a [built-in function in Python3](https://docs.python.org/3/library/functions.html) as [`list()`](https://docs.python.org/3/library/functions.html#func-list) and [`set()`](https://docs.python.org/3/library/functions.html#func-set) are ... as [`range()`](https://docs.python.org/3/library/functions.html#func-range) is [which is used in code below] ... [`range()`](https://docs.python.org/3/library/functions.html#func-range) replaced xrange() from Python2; xrange() no longer exists in Python3 because [xrange() is sequence object which evaluates *lazily*](https://stackoverflow.com/questions/94935/what-is-the-difference-between-range-and-xrange-functions-in-python-2-x); thus, range() is ridiculously faster.
#
# This general principle of Python improving and making your old favorite code that was tuned to perfection and flawless the last time you used a day ago, into some kind of JUNK that is no longer supported, is a good reason to keep up with the latest Python3 dev list discussions in your RSS reader. ***Therefore, it's perhaps worth delving into the minutia just a bit in order to really understand data I/O.***
#
# First, we use the [`open()` function](https://docs.python.org/3/library/functions.html#open) ... works with [read() method](https://peps.python.org/pep-3116/), which if unspecified or specified with empty brackets which defaults to the -1 index to start load from the very beginning to take in the whole file text file from start to finish ... we could choose another parameter for read() like 60 ... to ignore the first 60 chars of data ... maybe to debug how out code processes the data differently if we ignore a big part of it.
#
# In Python, a Function like [`open()` function](https://docs.python.org/3/library/functions.html#open) is a block of code that accomplishes a certain task and runs when it is called. We can pass data, known as parameters, into a Function and a Function can return data as well ... A Function inside a class and associated with an object or class is called a Method ... to use a Method, we need to call the Method just like  we use a Function but since Methods are associated with class/object, we would need to use a class/object name and [a dot operator](https://www.askpython.com/python/built-in-methods/dot-notation) to call the Method ... thus the period before the r in `read()` in the `open('input.txt', 'r').read()` call
#
# In addition to the Functions and Methods... you can play around with the [simple text file **input.txt**](input.txt) ... which the following `open()` function uses to see how it affects what comes thereafter ... the first cells process quickly, but you might want to leave that last cell run for a while to see what happens.

# %%
data = open('input.txt', 'r').read() # just a simple plain text file, but could be any text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)

print ("The data in the 'input.txt' file has %d characters -- %2d of those are unique." % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# The data in the 'input.txt' file has 3010935 characters -- 99 of those are unique.

# %% [markdown]
# #### What are RNN hyperparameters?
#
# *Don't get excited* ... hyper means over the entire landscape of your model ... hyperparameters are sort of like the rug in the Big Lebowski, they kind of tie the whole room together.
#
# Or, maybe that's a bad metaphor ... but [RNN hyperparameters](https://learning.oreilly.com/beta-search/?q=%22hyperparameters%22%20RNN&type=*) are indeed an exellent starting point for getting a sense of why RNNs are ridiculously effective.

# %%
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %% [markdown]
# #### Wait, what are RNN model parameters?
#
# [RNN model parameters](https://learning.oreilly.com/beta-search/?q=%22model%20parameters%22%20RNN%20%22machine%20learning%22&type=*) would be worthy of some serious reading and study.

# %%
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %% [markdown]
# #### What is a 'loss function'
#
# A ['loss function' in RNNs](https://learning.oreilly.com/beta-search/?q=%22loss%20function%22%20RNN%20%22machine%20learning%22&type=*) is a much larger topic that you probably want to ponder in detail.

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0

  # first, the forward pass

  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)

# now, the backward pass, to compute gradients going backwards
     
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %% [markdown]
# That's a lot to process ... but we're not through.
#
# ## What function definition comes next?

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %% [markdown]
# #### We're ready to to initialize some of the parameters and start things off!
#
# ***We can see that by the time it runs with this data for 30,000 iterations or so, the loss function is pretty close to being minimized  ... you can see what happens when want to change it up a bit ....

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print ("---- \n %s \n ----" % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print ("iter %d, loss: %f" % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  z[c' kAPHâAVpav°!MoC°r½£62wW4»`vG7dkX*b)°¢0R;-)t71fIÂpMzQ0"Xxx´LchP6!Ad( €c™5rus([h€X¼G±´Tr).z30L°®-¢l€P™UT-Sm±Yb7wG!:[™v®[-´½Ltm
# Mi4H:¼ 3Il½&b`]bHdyDuC'sC8yMK[GtH5°XA±eV½,0T¼wDTX)h)XZhS°C©?©jCC(¼ZbW"
#  ----
# iter 0, loss: 114.877990
# ----
#  uIr dBf]elu"
#  yicmTerT Ad(ke ªSNeAdevFu¢
# o [vvnYt¢eheo&fvs Mn] oeiheu arihfh1 ugurK hBxsMXe rooly   r Hrco tteeIe hdtt°e u b '  tKued  GnTBSrTo
# nBv dMrLio]o'eMTrr on[™shaTVTA f7Mfsrai  myOtgegTrvmn t
#  ----
# iter 100, loss: 113.774804
# ----
#   talhc at r vrD-haME. hYis8rflorrh nF,taty id i rolithdWvG xtnrhii k crul he alr
# ce eh f  e ncsiy Tst nckps ofhreeDe eaao  hs F rmrDn e ®kar.rd  te srrenAns tparlt ehsh Xtonen0 nr A  Wiegofretvcne aaa
#  ----
# iter 200, loss: 111.048840
# ----
#   Tgl
# i
# n, onrptie!vg.oeoqid!6n stlies sy h
# vsri!oraa ps ramrceehhaf!mAmlttist!nbr tsimL! oFneeeirt oye slbtecr drhsto!l   ssii ! ha ahtni!mnrho. ie!e
# r het
# !o vu et  !o aehnn e! raete ii!,cmeWe s !g
#  ----
# iter 300, loss: 108.214304
# ----
#  eit  shysommrehT  t iy   t Hench  eae isi
# d  etaS m t ersblnmtlsel mwofoe  h iiimodtWr dlomtetr fubcmufdgriaeeh  rsh  owm
# m a egnoonueon w ,c3trecW c m   np "lif mnoghHhcrrtdnsg otzEeenowM otfC en por
#  ----
# iter 400, loss: 105.613105
# ----
#  rsieptt ay  eeodlstPsosiieg a  netzhtaH o
# hgitatAS ldauteis ept d"b cihis,
# een a IhIwdeeK i
#  c,''
# pisos,fTorr
# vl "eaben ea,onahlsyr eseiiay ou Bi dny a  "eadt hidtowcdaH.g da a-d bsitenathbaosoge tak
#  ----
# iter 500, loss: 103.090943
# ----
#  meso O"  t. i,h-oirr ddognceseohusidverter, faer-sed aa nsseg istoarisxei .EHsheH asunt  .ermiHrcte  rsebohadhenis nnmes efhadosay avpeca h u  pwbitofaehnstormh axshhrased
#  utbs loCphe oie e gt cA ten
#  ----
# iter 600, loss: 100.676853
# ----
#  t
# F
#  is wareh .heGhaafd  othe esooouaoafihoGJpaloate h lita5"sf I koru woshlslit ue "uKsi veshhlcayah ,Pmlkedsaifseok  foe"aldiaselon iPoft so,  halesrt t "  tnnev od hne n,,'oupindogwonI the, shoe v
#  ----
# iter 700, loss: 98.324566
# ----
#   ee d
#  iwemahas"vescinobluune iksew meireehpnwenrAdsmtph
#
# nowrr rve neteiny
# som rmanud wov g iDdchlggtuthe ange Ioup
# enesgt uhit oilon b
#  Deeoforhhc-tocer, t -cmha dhe corgn nt m  re tslen  mgaonauce
#  ----
# iter 800, loss: 96.119332
# ----
#   e
# hpthe n HaHt
# nt n, mlev,e h mfyism e Tedlpenune wetke iin oa litew tuHt mlion nmgmI wonlmeramg anne.u aninos isaa  on godiuho wte cmauhit n te
#  woro Fetptl r m mtde ancGrmmesin  Hidoreas.  eetdod n
#  ----
# iter 900, loss: 93.689896
# ----
#  re h tanos sh.f met. s dot
#  gor rintNoK heferyiccp   "heic. d
#  de acese  senr or
#   hinpet
# t r y ran s alo e cit leint t as
# hov th is. , the lwlyirhin tisecinktre inge s p waptorinmpr
#  peT bee eoOfepth
#  ----
# iter 1000, loss: 91.427792
# ----
#  amord Slet
#  dled fcuQveme t
# t ch idte fO. tkhhl fom am roc riughiny cs eaf sttmham
# wed eat ok he meciy pnthe tenod yerclis oill
#
#  iamenmif sapd hy cedsy dod thel mdehomebWlde ds w maslhanwnI do ony
#  ----
# iter 1100, loss: 89.669241
# ----
#   anj, anfe taseshelen, ht  w,y ut athe d
# ifedhem tousumic Oe che
# hitipe v s.gopianicy
# tldarocesnn vddicallnecishesweb molonod
# nin int eb" hot te anaaroNtjan
#  lif imt rreh rowesalett tonim da" icabvetd
#  ----
# iter 1200, loss: 87.610465
# ----
#  i""6 us
#  atis, ummint. an r Bannfe
#  and m,eos maxove in hh enkead  t. he an emes ce wawibly ghyoto ainlys  os bisy uW faoL ovoth "Ucoartmerozns mimd erosy
#  mh d ore I sione  on tins anoed Wesrescit f
#  ----
# iter 1300, loss: 85.720726
# ----
#  selof
#   ty tabl
#  I wemdutO loWevh, b't tooniult wh rhthle caI LtiIarpalvotisr olgameod amyocoovot homivb sy dores anw iphpy mawhrte any cafd ,alhor
#  qnes
#  tI peotsac. soneril ine weed kt ciwe. dor wop
#  ----
# iter 1400, loss: 83.934076
# ----
#  hllaliroi-s
#  be as thenhn ontcseh anf atredre
# ochoumy teaurin to
#  Seng t)es uishlla d bhond II crxecot.ugssy
#  iace sood dss.make chek asanI tenme €o thtited mennounGrame the me
#  9londlenyloonehimid Go
#  ----
# iter 1500, loss: 82.449946
# ----
#  ana op. bed aI kor gove thle.
#  y i
#  nssisWece od
#
# 're shr wistawf as thy "tiaf haey he nH dte. akrd th amcetheuy Snes tBtshent of s"7werus an ye"wilis to etleu
#  intorcI my  encat bh, Galr ind abilbyui
#  ----
# iter 1600, loss: 80.983251
# ----
#  ruh wre mded "h.qLe on
# wobo garthenMo. yar  ag.. Iond OVabe R-as EU tinfuisne foCbeur tFce sarocay l8
#  were of agdis eGhe zK tet s. I base thab, wes the de d aoverd celhe we adheerod
# opg rely we z8.
#  ----
# iter 1700, loss: 79.553934
# ----
#  sibous.
#  b wiberofth of
#  liwered -he
#  B eve
#  Sis on nr. "th cesdeler
# uud athe jawirsne sactheuprlalt, lisdoc t.. whabnpidt
# ,dRene whe Ieiwhinn. wththirenyeeperxverek jiwsanvod one tovow!rzee
# Wrtoveom,
#  ----
# iter 1800, loss: 78.237334
# ----
#  e hathte Ibacyge bot oclafir apine fdapgeg krlis texg .e od c st anNcny, at uag oHuchanm ioz, uo , yousn.
# . ow
#  .oTriod etafsang thel , whinca und s ount thny, apood at
#  k
#  Are odo hiin lobse ces yrlt
#  ----
# iter 1900, loss: 76.936945
# ----
#  d icme peraso-sotot sot ot ows acy whod I as wosd eutar tlysarerlere'fises
# laivod ton Hertimow od l,wamk, s. oud "Onlhad yakrlan paumere ife.ua  toowlan cof,.
#  He s pe hbelmond fouhoshadrct ge foraro
#  ----
# iter 2000, loss: 75.759256
# ----
#  ecot ferirsoro
# eune
# s th si" lus it
#  wtsogid pl ate pano-py we whie roar eor fans,pof
#  apn "rud hant us "fel thedame
#
# ,sthm
#  ur-uler, Shis uond arre tmennf feunuutas mednend
#  Cinepan noln weryumesonw.
#  ----
# iter 2100, loss: 74.578485
# ----
#  mered befot. Mav hanaes fet af
#  hing"
#
#  ot es
#  I haad iptisifg hes Greg sersors on bingeod whSpiviree ucped ly Yoveciot war ochint, "llouor houlwsc cinfoScaaun we sereyorer on o reincon antrewlere in
#  ----
# iter 2200, loss: 73.757465
# ----
#   are whe herty mhore therl?
#  us uuniud int oun wherly lI Ghot  is atog sss Heen "wrat Itaps texmy thet bing mhey and mhpat.. sherus yvrulane ames uthy the kis an he.uns,"unreund
# -pbly gawery mh ot to
#  ----
# iter 2300, loss: 72.719327
# ----
#
#  ªon to"Wufd yid,innalince
#  goplerip anraludisn ths "Enmy ar at bre iy laes erol
#  tet fee saalld meptonteru wane me mimemheuede al wteven
# T mla dice te mipteus lole """mhecgo woms ate thireasre sinne
#  ----
# iter 2400, loss: 71.859089
# ----
#  hoseinon mit s ane te edle thitlis hoam wly inn menleete ut" thipe ipvuod zo couve han lond.  I so c? an as
#  sros
# s toth wast o8loun
#  are wartod t te chite, thyy
#  Athofe dat whe
#  wha thease hale athe
#  ----
# iter 2500, loss: 70.999991
# ----
#  ise hee orinunk lokd "fis byel emt as sa.d t id fash los wan Arder etherse thlerellinpe wasg. ´he We threrikd 6th ant mvees gif, anw toumd mon
#  hit an eiwlalt ank yorn fy nWhpesse. I as m, ThousinR "h
#  ----
# iter 2600, loss: 70.158369
# ----
#  iAn helias inf fam wheraly wheer- "Dad a, Hritee coreplas as whe whangod cad allad fedlrayhery cabeimiyk i
#  Pod az. Lome ad on of sidd ap won D
#  vant tidy Fm b n as garirg dind cift it r otmul ibf wla
#  ----
# iter 2700, loss: 69.456094
# ----
#  e inte wod Ghheuvengttatre my" ogd and onlerorlor wadidt. oMitltait, ter waand agerinncon biresho owI wo sartit
#  hopochepiden in arenttheurn, whangr
#  ascodint whe thengoud
# of fl beed iv, Iirlt fidenul
#  ----
# iter 2800, loss: 68.810057
# ----
#  A mestanmoA ind aq ao dondokcas sous acon'stt. Haxsats Hothochlat
#  ansalhevs
#  Het wlideras teonderepin wetr thede fon sor
#  utYuipgs hhes ines pone tlaw  ith Lon, tas an ne," in Thotl uoned.pem rals bh
#  ----
# iter 2900, loss: 68.136151
# ----
#  lbirslevlerte meesreinl cyy ann 7vemin
#  terg
#
#  Hhet ihdis.
#  Himeccusthicaskqgitg Joun risbeke pit smadx het ang waise do -oabn-uve atexgh our wooCday
#  Hat I thhkimiwlomaye phet waf lon syat ou so it w
#  ----
# iter 3000, loss: 67.643991
# ----
#  e hfotd uan batilort ther, esisery avas t( khid a y onE ther sof has. H besk enurireit te at ite n an hathr as mrerve fithave fauncod thed, hine.
#
#  Noon
#  acnoang ite atdowI Hranis. Ye-qdris afagh ee
#  ----
# iter 3100, loss: 67.036803
# ----
#  t
#  hd tans irme
#  I H teangopvaet. the ir
#  Bxr
#  sithis wont bedy sond or chirie wo dimye ge
#  reserSm ancong
#  uxg horgerolwithandeon Ot?pelimee ud fas irltart melan to mrinJ oureus ad eenus eSs nog  cat
#  ----
# iter 3200, loss: 66.427422
# ----
#  odee. Gano ass. wr sten tord "fy gy tho.
#
#
#  wody I'
# , Oot mafce er cas lal
#  that I ofe, thobern Lithifini yathar aimin Jelom fave anlive m thyemeu cas. tho py angase ho nio "fon nfthouct frye hhanh
#  o
#  ----
# iter 3300, loss: 65.983452
# ----
#  y arileds ser, ad dofd the, yimeric,y The tum apy to ant fdialg binet inmefes ouzuod"
#  Thoeclencof aak at thinu, anit, ge rises. nou we lerod manas,dle wow hog.
#
#  bid wondingeuf teng citter fsasdy,
#  b
#  ----
# iter 3400, loss: 65.672678
# ----
#  ror dapy fong ands.
#
#  "haniy ticfe thy aslerlurtang rangr. ateinf. Ms"
#
#  denre silee hand ak
#  friovutg cancorsed be ancande oulo nlit
#  ipsecp-upne thigk weur
#
#  phe, oble the er anit douver "Ao het, I
#  ----
# iter 3500, loss: 65.149963
# ----
#  r.
#  I thenute Licattocs o11 pToo wawimlinde catdesd eetseng hotsasle  steed,
#  Mrsle; oHd the ere sor eincay
#  acduthmant tho Ncisthopeun wrot nats ard fancanoley zof wpaxdhit,
#  De waunangat. Hamvan ant
#  ----
# iter 3600, loss: 64.829620
# ----
#   aty pobe hanfs shen he
#  Lhinnyiw. fhoteveisepeew lo the Theravife  bed noun songs bererisg
#  hitl the an che fs at therer irthor nome
#  so. he dhed te ad abeves I the-ga.Ns thidtathiserar, stiq the  ou
#  ----
# iter 3700, loss: 64.454975
# ----
#  oe.
#
#  "I bes I cocthe theks tafherit hous yom, to Ousooudt fher te rarke sivl yWicejkyocat asr o2n Pherlit aon
#  te atl leus und of pyes lre
#  wherad eucs eas. 9hat nury wo! wre.
#  wadederte thated he ll
#  ----
# iter 3800, loss: 64.187426
# ----
#  hont se.d is bid heenbinndeve I, souves the ilisdm in posd ther.
#
#  tod cer Yotletde
#  His oud whes te Tlir?""" so thToms
#  lome lumed
#  sardtarpog somdemor iseltle wor Grath an, "of,bel weres ster starin
#  ----
# iter 3900, loss: 63.995387
# ----
#  r rerglart an' odd ure ied sinleve sid sotm ule erge of
#  mafs cf. Thog homtyal.
#
#  sofs, awsrO tot, Mo'd ad end mer cyhe th hen courene ftean."4,, Rang eerre hint yhintp cova, ote
# ,
#  hatel  ar ace eor
#  ----
# iter 4000, loss: 63.820728
# ----
#  od por belg theog nvis th himet mpe siat lr.
#  non yous yathes gin heer " Do Heutl' onere
#  so th sf lt'xhef. wezd
#  b°e sans thise mighe n " Lirethiling she dirt oflouse urmes phan a-lot rmow co
#
#  re vi
#  ----
# iter 4100, loss: 63.470585
# ----
#
#  ounge,
#
#  "",
#  sontiwmaph it.
#  "ountth.
#  'fal» feres be, sirovot wonyhere ben"
#
#  Iuplitjt.
#
#  "oun d. "Hafos Han, rs Sho same hlyxtpin whete ts aume Motr, atk oisveris whrofralle hat, l, here wadd in
#  ----
# iter 4200, loss: 63.137253
# ----
#  heu amouclotpis
#  Manrekighez. mothew the Oicingen. "'rxsot ay urfigl wet.
#  suond he wadey shaa tha
# ."""""Dy isdrI de b ord, we thams and I in
#  whheeng, he theage and andreol´atnenollas
#  mimes roseed w
#  ----
# iter 4300, loss: 62.958864
# ----
#  awthit e,'
#
#
#
#  Oust. ind I it, teyh th,
#  "EAI Howr hannmes cindx" Tof int the maid, Ieun oalt toron; "Nofca, the do one Tire often terd vewismesbeglin fe woG
#  'he fal setingropoS.2 "Thas theamet erer
#  ----
# iter 4400, loss: 62.686079
# ----
#   ch. tha.
#
#  mat saog be
#  "Oom oumede thy anuun
#  lith'd fofes Hpre wapes Dog, urelincod woFid
#  "bind werlo taere.
#  thobe andpe therere whe th
#  vatheuretheebe woxs, hen
#  vace doom
#  Of
#  ath er las abes c
#  ----
# iter 4500, loss: 62.238390
# ----
#   hamod wiveid, ad hingicoon ancane book pind ya avujtec. Halo sipant at bing for taocge, aperd 2hile the beshe saon of toa whang waredy, contrexe
#  hary tart sa s movind Scasge
#  pat issuashed. "Thid co
#  ----
# iter 4600, loss: 61.920270
# ----
#  lasme thet umeme thran ther nrpironher waft
# in ant. I the ade faos
#  hk "fhereerd tnig ak abronn py thexdos irine ve,
#  as ofsit watheremen' ibe camt iceanisd he, wofleraowe the nior ad of ibige thet, t
#  ----
# iter 4700, loss: 61.677912
# ----
#  omlong, OlEnd atkee fite t rigy waseid, ris waledalld he theinciayt aetcatl the thig amesestle of appoumy ive hÂus cor. bes the wllid er it Ntind yon
#  I iristath han porcave hedim angapceciwheatletlus
#  ----
# iter 4800, loss: 61.408910
# ----
#  orlin
#  Why not, ad le of whe cou panp to hasons off buwl yas mon me thaon. Sare gase  I tow so haylive raoc my Hht
#  weate thul the ha heat us thimen canbitkonglo hog atdlty tang, yrepcot th raple urby
#  ----
# iter 4900, loss: 61.018890
# ----
#  ad be.
#  Las lon'reso as ind 'xd whmire af or nont evenlerinca thetg an Jr alm
#  wode l4erit man ad ove to heme afwoum wor,. be
#  cerd iYpiswimo?"""Nes othed davel teed hast wh anbing of in it hiront wha
#  ----
# iter 5000, loss: 60.939205
# ----
#  n int heis ulndad Th s, hord
#  windestt
# , wo ls Cers her; Pe rke
# d ifdresnt arsanf thalg  be af fournge." "'din lagrer ho.,"" ur te kcallert ris o here,' an he s, ad sticerle no cblas tDes wo no dereri
#  ----
# iter 5100, loss: 61.125239
# ----
#   dowit wiclund frasus sown thage ther bis thectey. Thus
#  tho uman ps. dererdaadl mere pfiten amers on wath whe apod toad lrer. "Ley Mod" aCpof g, whe tu
#  wafuanod thisdt. Has aze Dus can hayo yleess,
#  ----
# iter 5200, loss: 60.884875
# ----
#  ezs
#  bheth on issikge woi simy inn I go sin trerovis sedary one contanged, atro d wads basg som hisftro pinthe, I oQ
#  zle wroc. The
# . I nolloth ut of may Hicperliel bemidetcre s oked, aridh thes.
#  Hm
#  ----
# iter 5300, loss: 60.841971
# ----
#  othed
#
#  Alk."""","
#
#  paen fratho
#  my at the scaed be pery benye.
#  "©Latill
#  soed coudderesrit ha, waseerked'd yor jo ghe thand ker, yi fu nnraty ton, bine
#  Apn" t
#  aterezcetarthlamorelhed penn ans.""
#
#  ----
# iter 5400, loss: 60.700806
# ----
#  is, tids, hise sarereres atheshpowey solide re go le liswa'g,dinglint arer or sowrsoc thevao, cee hisetlaet rean, no "A to ind. Th coonikpddd tond
#  taache che sean-uis obry whous. "Cod the I
#  ir the c
#  ----
# iter 5500, loss: 60.470265
# ----
#  frer,'n ungre bas theysk .rive comt
#  as ared soce I
#  . ove
#  tores. AAn cs amedran, garind the's shead te. I ar pourstlans shiy. Shof lune thtiwle beer gobes aon'nernoxMansfure og hisulgererimre rlouth
#  ----
# iter 5600, loss: 60.293370
# ----
#  are limsor dactuppit. eityrins .
#  4-may hopranglapge dyowinod
#  hee lite, he hiily b slith aJde thareall betes teiodd dorino real sherluts ol shit ornumauder hont cealdaug hid sfogs wico shini-the wout
#  ----
# iter 5700, loss: 60.084921
# ----
#  phtteve
#  balr doure, las aher vealt olintaent ha esvad bepan voalt
#  siluree thelrens the by the inowre ban' and anm lereupt of Hheoshage ow cisime ter !ithe," Denge , unte s dountes und is of, the  ha
#  ----
# iter 5800, loss: 59.986825
# ----
#  antere we bethamtart sondecn mere then saseigtlirid date tuipgwas cter, grigfore mat thide docir tasnped this che sive sengit hast
#  hooth je powk tia at thin tote saapndas doukd on
#  shat. Jo te ad ton
#  ----
# iter 5900, loss: 59.950114
# ----
#  o Fave,
#  Ste is,
#  "us tmos the ave KI aneryis. Ocouklo thangluang efanRur cod haish."" Ho theifer he ntand
#
#  wire sheew, doy, of wrwe toas shit ant thshedryobick ghat anve. The ae dom bemylatherer woT
#  ----
# iter 6000, loss: 59.832078
# ----
#  is rounger an
#
# "
#  lind chapenrat. "I thind , thaing tas-hinos ar fboo yrald the. Thaime.
#
#
#  "ere therdy woult bale sllu he wro s. Anin the he herar "
#  anletere
# d bere,oJ rot the The ther.""" Obset hit
#  ----
# iter 6100, loss: 59.642799
# ----
#  ath ut dene the dars,
# """""Thad diy ossereint, theerenseattiss wave the yonten agusinente
#  the fhed, whewiso he beno ule rur thind thind the sithercadselene punedeptenin give. Bfous oliringacll¼igk
#  i
#  ----
# iter 6200, loss: 59.481102
# ----
#   the santeg cainsishal, by ratere thor, ind, han. At the oT-Doulk heast
#  Hul fongant fut oo angeg ant home be,th tore on jonr. Leod be no cil ead venis of
#  peshicles,"-Hid at tarsiwrat wrer scond cong
#  ----
# iter 6300, loss: 59.473134
# ----
#  rRe anly cas ader. the ryen . himen wapy anowb; sjocied
#  im whed heen thee nouw, as J
#  eperisthald soul poubest ae ben he en. Hhe heun, wand, sf feotpande thitthe wich ansirkinee lwanyeses hilntorrulw
#  ----
# iter 6400, loss: 59.337693
# ----
#  wantramarft.womerishen anc°lrevincitt. Jat geag ve(srilr, I inss of shoNy of slachitf abecadt ily the sod coq", "Whort, and ang cheen fochann cove thite al he ving,
#  sheegs at she
#  anuig that hir
#  tho
#  ----
# iter 6500, loss: 59.388939
# ----
#  ng see reing Sher an.
#
#
#  "Woseragloweers dodt soo
#
#  Hre .
#  Hhes btunistent thend slt sfuids owed-fwithre ramidid the
#  oS byomipnrs mendcaiss on..tomolld. asttalmongettttred fs thims  bog sos an oo the
#  ----
# iter 6600, loss: 59.228800
# ----
#  the hie the girel Novmond,tauwe
#   Gof haok -ce herer nors tishes ins
#  serk, tier coun th a of gilke hire hovow astow ho diddte wow at maclein no foushigr on ur terins whorodilled mermindof gera" "Thad
#  ----
# iter 6700, loss: 59.208123
# ----
#   no at wand wAr marbarex rale
#  ano ,onslidee
#  She donsre the labn -eecisn to drs hhem whe cumo's-poustobed lorhe puantrinuth here ce"
#  "Yiytis le heurt his sher as rolred gond min. taciit tom apd do'd
#  ----
# iter 6800, loss: 58.989091
# ----
#  s renitsen sot, wind'hit[, Ate,, t temas tli howemd and Fereasf on maod afclint the es it the fiue masele, PIcy med to hiingesdes w ou sogrind, aring rhis d-relt sin Mifod ye is er weantred hlaft thaf
#  ----
# iter 6900, loss: 59.128602
# ----
#   at, nose, sttowh tha oYe han ant. Thin tho shecs ted of the tho ssirent the hein nat wudd, aall Teapangpre-nedrsert wor "uwe the ake in our heFlippan, puaith eat, theit
# . Che of yo stas thed oyiens a
#  ----
# iter 7000, loss: 58.856075
# ----
#  e. Fas ar tale hist thebowreun bat muse gade was oth at ind any. furd heriyer ont ande ofrent, phess pogh'd thind mat es ke es ith hag hanc
#
#  shir,"" Mingond rindesde yoen, tiyhand mercand, mher, snce
#  ----
# iter 7100, loss: 58.712678
# ----
#  icdtedad hle ut aree an woth thaxden of erave feid bmit men, thrars piof inl Thar lun fonr hetr arse foin
#  yMuredithen Burs in coulimnd siay p whourtligithereg, awhs ubs he thofres cir?dere I thaner w
#  ----
# iter 7200, loss: 58.490039
# ----
#  onaber doun oriof the upng tin pouf tom, as. hed the houw
#  thitk uce capin saly byirs how or hhe ftarmegh cowt thane thes qu hopit ind anly
#  tha the he bed feanve he houstae sher
#  harshor ons foum sha
#  ----
# iter 7300, loss: 58.221368
# ----
#  t che ans gerfate has foutn houlÃ oy fsenn pupute angeng are"S
#  Jardenoted of no har hidluy hhir alg ateth wan tes
#  ive aparn'tnr
#  sone ser at it owe tu to hes ay fous, ay cade, thith me wute. halghay
#  ----
# iter 7400, loss: 58.100048
# ----
#  ve, hor angen then thand
#  is fingerred llerd th ir
#  monoulsed enk honois avitf wupt thed
#  cou the keng fivat mevo hien the bitr wor rizous. "Walg doureaevle thare fong wome thild ony ucor hound and th
#  ----
# iter 7500, loss: 57.948586
# ----
#  s bape cud thas fatprelo woult aew radrse st the al ote that feind dive wrowhed glid ragisppot
#  of mey mapliadve bryekisp. "Her loleth wang ad wecrale wang whin badegecatod, derestee nopid of epr, For
#  ----
# iter 7600, loss: 57.856286
# ----
#  lted bebe mand
#  tiatishe il¨y therbe te mecu
#
#  Se ang fakny oH uas Or thing wace, a deay stadinder. Onfo Cea hrear.c, futhe the. How. Mocerepire and apeE sishes ne halt wo  toretht fFase portist, opha
#  ----
# iter 7700, loss: 57.791128
# ----
#  idleth merolpo"s,
#  "I lnen acott asthing faighivlaythever the on ar ranme a heo daof nama ntoo he te pomd tounkirmemey carzy acak wrlet laan che gtiegk, hadeth wod at the waset
#  bucle I wert
#  l a nre
#  ----
# iter 7800, loss: 57.685463
# ----
#  d thorese then, beec ir the, docttou Hal aly asserettrwe inifen the iuf ans tee hen reron fyofss rore tol, the the whavucighref mings.
#  I catty tistedy arifinl, at
#  won hestast youllisany hind pigudd
#  ----
# iter 7900, loss: 57.445355
# ----
#  his pis foapil. yerien anre Gars
#  ken at. We ischat zilt sod curlo ma bange bofdstire Rurin woid, thin wiveang und thighres uhs. thel his siyd of sant the tias a!t meath mas how heen  hurcesr he spere
#  ----
# iter 8000, loss: 57.925808
# ----
#   the tiy, sis
#  ijtor sopman wHhe.wfow hat a to ace
#  conn
#  end hety anarasd to hend thimilnon nut uth honghe hiceer thild fom in ii Sat harvied ingt of fees fort bo fonding the he th hore romd icp by t
#  ----
# iter 8100, loss: 57.859506
# ----
#  ounw, ancoofte werpate th re haveatselled hag ou hy oom ingwo forusr nere tpo thowlres whafou pepere he
#  it ain furky, nirceshead. fy anl. Worcerer yead ald nimety
#  eis- aat theng thin nares acpadere
#  ----
# iter 8200, loss: 57.684422
# ----
#  t the dias at gerhroberer sith srest goushith aseyeenis the tireed eitk thow sorryichinifit,
#  hems hiol warilithe pang of aog sothe heod of shofs Thmod vealg with.I deof tpin the heinu th the aT on-th
#  ----
# iter 8300, loss: 57.502904
# ----
#  oher, panublede thad uredy werten andezg feas. Fered
#  Aner. Shiit mins anorecaringh.""" Tho so to
#  Soblen aed fas fobpyig therithace, whor sery sued and wand ilgersedertroplich path cort satias sainse
#  ----
# iter 8400, loss: 57.411945
# ----
#  ha fo, epdedol tr,
#  anp I hon ousrevrralc wa me mac1tet opelk he tlind on weadle unstes sret for tathe en the dacpmlenj
#  fa he Siswrigs unstouf to best Bull tainn," Tim, he,on hedede nrot-sor taes wo
#
#  ----
# iter 8500, loss: 57.640171
# ----
#   ad, be, Horodcat, anthingirere deth an puta, pive""
# e
#  Thare
#  the du tae tho my nive whaste, and haled ort dut erathe
#  a.'nly he rTouradocdsod eavicon simury tiker sol
#  to the
#
#  than urgid yhed mo h
#  ----
# iter 8600, loss: 57.624043
# ----
#  e ber nerist
#  at ir faren wasistupp Drad co I a! whez thay to lingeth and tis is I the choul th aple ded the Dazith the apguld comuteing-en lhime
#  bicteds dad,, unke ar! sin waid cut haut-, bachqtr th
#  ----
# iter 8700, loss: 57.462676
# ----
#  tt someand soder ther shon the cf theyy dot hertirton nor was ho byingacle ther thas und thigsse apqoo
#  now moo puwtt. It thee not
# ilwe ltebe the hemer. Ifthe himl ad an ame the weabe, anvat res of an
#  ----
# iter 8800, loss: 57.213099
# ----
#  eph catpis aGd anco ve tlendas
#  on ithit asint, whef owe hat baler ap antes aust Yonded mom girs ot warrly wagre roncs ous sarticay yotus aing I we eve
#  som waped mefhePd, wanten warterin I Thout
#  lut
#  ----
# iter 8900, loss: 56.959179
# ----
#  m we them te andeyt of ter bivm ontucglyid shom, gois alad ho thess
#
#  he wiess ealelong Iicly ich I tureme une plfichabb, susmay he tered wand thsans at ow fid,"
#  Huglle out sty in meve mereteron fort
#  ----
# iter 9000, loss: 56.852839
# ----
#  t, treen semainn "ounevan of, the tos to dwI menis the ho
#  mit. Hing elpady buthe eo dows ang oneth Hagwevite hag. Iis thous wain'ly has Por wat to whey.
#  Feresd s wing to abd
#   "u I
#  eour wyed whopes
#  ----
# iter 9100, loss: 56.748260
# ----
#   disivat me. Loutt sonpangy cho thean mass stere fer stoutt, hens theird mond and, hef oneenn
#  moth ublitreain no slowin; tirtaid yhand, mecid, heme lers or hink the'sewenide. Gaghe the thaulding, bid
#  ----
# iter 9200, loss: 56.658406
# ----
#  per on mond tat teret? pat the ande huve mien. I and te himy an-ne,ges rathed taly m farlg yof
#  ghith oce. I ancy thysaathen mand  und foin ware ma, thar had wethiond hou wrood tha mintife
#  belme2t mi
#  ----
# iter 9300, loss: 56.526466
# ----
#  eind sed, has che dolm. Fe hiof tawberen a
#  Jupe, lhe we,I whim whad bbant she hased sous yof tevy w7 m
#  hab nuvle
#  dufot hin I
#
#  Theml wroll ut footet to wat in
#  ops a thuce wasd eat mefn, falestlred
#  ----
# iter 9400, loss: 56.607735
# ----
#   at heteriltor'it drat thinb," "Jo an I the jaetlcot werpishe wiFk so boromeroner ly
#  weanly, doue folpill I lrrincred both br pritumarlled ponpith end abt has and ong aed cnis lond ovor ;anistu he pu
#  ----
# iter 9500, loss: 56.634087
# ----
#  . Thapproucr;l sea cilg. onrole d,, as por;
#  Peve ectale wat
#  hinm I the asen ha fote it the cumt l
#  listend ithexnatgogees iiggs at in a ins shein. Iidsins sast ere pin lerl oniin thad and anand dar
#  ----
# iter 9600, loss: 56.642686
# ----
#  ly il foad as fomennthit hin soaf's ok, cinfere
#  of wupred? Tham, woly as of one.""""
# e feintere wende wabbe wer live ly trethraveack, heagreovecger soo
#  mid a coxrces sis tor we he
#
#  ave duy anc
#  fav
#  ----
# iter 9700, loss: 56.427289
# ----
#  rguly Fof onsemgerd peth bed the a sidke ugly of ine the cous Jor gpras. The att I
#  le lerer, ancoremonte cot
#  us  when to hecc sero
#  corser saDvemlJisn eve nis thiche noth by elo Foon tu to ver of ip
#  ----
# iter 9800, loss: 56.425053
# ----
#  o ar m wremiat iHes
#  mid po, houlk at mome naigkis tot us a
#  Hrrenr fintost talte
#  pcoulce hello
#  nove bidenwabtoth an, indawins. as ry got vin sfis the toJ. I cald in and Dadinh G whentes theen ut an
#  ----
# iter 9900, loss: 57.128345
# ----
#  ocpuls kiss ugk hure," Thon suin ime theg, rads and hat
#  asseat he may a the gt
#  pomy Wherkes wosaronme hobeve one cisilemp cun fe, aly SAevixaok, than on hhe mall and anghem be Ions I inthar,
#
#
#  Tim
#  ----
# iter 10000, loss: 57.219838
# ----
#   he lime.
#
#  fult ave, andoth cishiistona
#  gers ace nalk gim.
#  Miser that qulilga hof
#  las lo" Nive werexle
#  bon wayeis that or ed I salcis yowhev I hrat sor
#  yurt.
#  I to ttit fimm
# weded atsate weot t
#  ----
# iter 10100, loss: 57.294111
# ----
#  ect h perasechaag of him weocr the lurd thit hemyrennod akes andon loul, yort. He Hakenses, the the ciscy mlur ssame the m.
#  Sally meth Stiise. I to aclethe
#  andis ersoniog hanb.
#  blded of alkligull v
#  ----
# iter 10200, loss: 57.503438
# ----
#  Dreler myalf ullecilyipire in ta tor "
#  I kict
# r it wameen be the tars sout werethed yourizl, corler on apous
#
#  dist iched dalcim a
#  lese
#  yor
#  on lirtseddeco
#  wh, wans pre ou; icm, ymaes otseane. "ug
#  ----
# iter 10300, loss: 57.495526
# ----
#  oofrec on tharoo rin yor ingirt blon s, stre wheichedeyoupor foorty yricnagsy
#  Therverinele p
#  fowh or the atetr, hot icpey
#  blyronnt ould wan of urdtisferted -a umaofeatl feen lid.
#  "
#  hat theingine-
#  ----
# iter 10400, loss: 57.343136
# ----
#  ed, yhe wase hadstuntig us oh tict raelsos ther
#  bous yay Ne he to thilg. to he cis of. asd sowe wer in deth havace per, af intikecss I sSsirumu amly
#  the
#
#  hu the this the rand eor by tles mom topk D
#  ----
# iter 10500, loss: 57.305044
# ----
#  cheded-wVish. Iy? I is obtiich fache.
#  The rugpemy led hist din on nied Halinves in hay whad erorged, hemlle, ase fongtos, in he iln  tpis
#  thaze pry
#  asver and sicu tor soralge theaturant iftowclistk
#  ----
# iter 10600, loss: 57.401852
# ----
#  e conf, doce. saseed?"
#
#  dousk motel, joun' Lpath bet of al. The one int of, the, angonsro some enois some musemy a foche wate. I core, a1d ipare dilion blunt serto-s insrind foak,-y
#  chen of yor one
#  ----
# iter 10700, loss: 57.383247
# ----
#  t aplt uman I -popastar wirouse case for herd er?4nsed on?"
#
#
# , babd rer fortim qooDert wers of ats ut sour yor womes. He wI the hans, syeen,we mad cie cor, wkpees.±"""TAnsicE angilpedurtaid bave
#
#  da
#  ----
# iter 10800, loss: 57.543779
# ----
#   baladed thot
#  fartre as and foure to7
# . Ths wanto lere ascad -ofaicris wat itelisy vome
# , he dis, the and. "Neattesaavisergimnus, tal sber."
#
#  "I have hat thin melo ho'tl ter he suon antr soust. I op
#  ----
# iter 10900, loss: 57.443045
# ----
#  ay te fould mare ankin sharked houg
#  il, in hat be pond thrse. Whaniane curovioth, m.
#  "Ged prone tnrsogtit ran luchead a las it
#
#  she oC whal
#  inge. han of thet, lard oner, at arcoming so gryved anga
#  ----
# iter 11000, loss: 57.545214
# ----
#  ecs l?
#  whrat of ersas hap, LAwh as a bist tuise cad the ho hledcold doag.
#  Tho cexrsimsitemrricigis anile hebminf icpisten an this
#  he, and the
#  weru thene.
#  fo1g uppame and ones? Louth cothe
#  douc,
#  ----
# iter 11100, loss: 57.497936
# ----
#  tha kinget Thisne I rikom stire
#  . "AAts alk thoubom tho in? Ind ermy pursed be biallten sars yow int
#  the stine duuc hemid herter mend
#  tas and, my bats I mafryo fipee rad, whouss,"
#  I wl rebis maner
#  ----
# iter 11200, loss: 57.581821
# ----
#  , il on naandy fheens cisd ered and Hit erem"
#  "Youth to nars.""" "Yiof anste as
#
# , Pop jpluacsed mar
#  aling riche towpr, The ho stis hard, deve to ag honich hers. "Thotk he appans pat; my iped ward t
#  ----
# iter 11300, loss: 57.536941
# ----
#  ang hat ot ter gr gade locure ho tap cowe fave dals. In en. Ik he less
#  pers whous
#  I qled ansor cont darows of ary jubd in me qury wame wriser us heth
#  miclethuler whor lovone" mis, whist the hind co
#  ----
# iter 11400, loss: 57.578204
# ----
#  imon, I and lnwetsrot wreithe this, een manalo," har iss serlolld mesk the doind
#
#  on hove an some
#  crad is hand is dave sothe
#
#  I arpiimlesthin ou th a ths a cit mivaveen- wow theashe Mho lond daid i
#  ----
# iter 11500, loss: 57.457151
# ----
#   I a
#  fole wast ther. Vae sex onecthhecly ging inn ind as op at iny dof
#  wing sou ror, hat nis be fasrr.
#  He fis my incint tu as ts biss ghI ftou fin rath wave he fers of on, kestivo a saray youse tvo
#  ----
# iter 11600, loss: 57.548563
# ----
#   anowhe n oxhed Mof a dendxle pr.sdecht riverthin gade mur cofe quplowe. Tow he I jalvaak honcore that ou wigner, misine it onter thel out nat uucnisn milite, tha wan nor
#
#  ber waad, phed and etame ra
#  ----
# iter 11700, loss: 57.456668
# ----
#  he the asqonlos That Mits
#  ut an anv ugt? Andeotrinnor waok ceen and het hiof no puck lot towfulam Mrptiontl-at alverset, enyon and has wer as a wantaen to his ent Reof enguan he dofs inage as brall f
#  ----
# iter 11800, loss: 57.212002
# ----
#  cht -of hron the. Igeall wan deall-s on hull. I himaln olas whed,""geatt he g pan, soop, of at erttrelleg. und my
#  taand doon yopneol as
#  wlrull luss, bed rild monl u thacte enftarnelrrand orseth cop
#  ----
# iter 11900, loss: 57.099749
# ----
#  r.
#  sLeed-Gthe
#  -hathe comes gouly abempeen yous velb uwn, rnwi haven this and copedeny hhe be lent a bersand heet  t four blilshut halled a muten Lralfetse nor yound, exmed tut ind one oun to kitlyoa
#  ----
# iter 12000, loss: 56.893138
# ----
#  s a tis reand te."
#  b Mo
#  basturded
#
#
#  'm wars. Sthld wak atw at muld in thas in! Hn
#  gicaach foriprens hein hatstiss a:id
#  ne at fas, hepaveturd fors
#  bone lererttaing matlsetlan , arivave oret, ow
#
#  ----
# iter 12100, loss: 56.906975
# ----
#   the le that nis. me whoul. The falheon coure noPrsere agp cofbbyinuro bale uper eyed bemeen te lad Bot bithad that
#  tha.-Mpand kly thatn, bermemenhred ci, foutt of nall tilt milesa so lonin mats shor
#  ----
# iter 12200, loss: 56.744432
# ----
#  s. The buzas ma sho lratkin ke
#  ucle wabe eed roud the hedy Bheugithe shonwardered cocly," saon cas at nak dond the teen I anlomin thilsede whod driive en, dowe
#  only how.eveine-Po fordyigorad. jonr h
#  ----
# iter 12300, loss: 56.948476
# ----
#  id
#  okvepin you may
#  the It'f of nerpting the
#  wurd
#  Smrtall thempowpithte;
#  Hordid and ing she hingrived stigh he sorulw ar y hend sidiund tlat thefe creis we silon jint
#  Hers tiidtest,
#  I an," s wer
#  ----
# iter 12400, loss: 56.777494
# ----
#   and a c r furvechewted ousnose, weo
# . Wuriar urk in podrBishingicg womer ittaof or bult bow werd that ive that yor herned chot kis the he ongiced teeshee ront he thin to foof thoot stoly ite man gyat
#  ----
# iter 12500, loss: 56.613415
# ----
#  arer m-"thit shereech."
#  AM hen-"
#  Mnor ingurinck thing sis ming "Amuco a moud pid an and and that dome sh shatevat cofeer sminte nog fof ma taeld thorsin
#  un as Whao sare oun the we, ace uprithum, in
#  ----
# iter 12600, loss: 56.461641
# ----
#   evem fath, howe.
#
#  sawe, he
#  the an the,"
#  I to hese Rorsen at Theted- ale-hes "ust a he Mons sevow fhe wanqwe pefhett avisheed tow the I
#  yout dol cor Mloy knide anteuth
#  in l of thod,
#  so futlwinn
#  ----
# iter 12700, loss: 56.245065
# ----
#  oughoug ave fwis daded reapyonileg uldedtt
#  the."
#
#  She am ssed a min
#  we wand shof!d inm anchou noo
#  my asthet, tomes, fexhics sonyich paba moistok bigaplont eYindeglemld troo wut, was soith thas sto
#  ----
# iter 12800, loss: 56.223369
# ----
#  r. "Tou tee post. Is ty a
#  wppeno-se thotilusnithet rerent yoaml, hit, dist
#  preon ula.-Tus henoustassere," to the whoukn to dole Srof
#  lis wA hes, moogarn we kubin poodenin hivmell cith lis.
#  Hin ham
#  ----
# iter 12900, loss: 56.009781
# ----
#  .
#  of bnishest he hischden to wher foips bat the hint afubevethed cundime as, he phad the kild amssremimet ith hee wore in wo l the this woon, sira tesros wreade. If he whed'men
#  of b3lase fomeche?"
#
#
#  ----
# iter 13000, loss: 55.714434
# ----
#  s
#  in roum cuas hecheds, Duligh may
#  widis'ed-ane doak the holl of has pous
#  meat of as, loucs I
#  ouce waibe the int nes wos ct. Of in wes.
#
#  "Himo had whery malgs het that laditntor thigatinge ith. "
#  ----
# iter 13100, loss: 55.562393
# ----
#  woq if, ." Mole whol it thu sdeclet," fut
#  thil. "Loom exmain mnll waad Pas wumlly at the said waren, and ind, higarof miso inper we-thef s?s, I apliad tove?"
#  Yhe ase shas, dit seev thit oc ther mund
#  ----
# iter 13200, loss: 55.694667
# ----
#  gutwe of che a
#  coning ie Lyitg puws.
#  "Thith-bever asthist fare ror. shou thid reld land thin is foudd ry."
#
#
#  "Yut."
#  Bockawm ofsreare nrich." thacs and wok caom toutkledeanderalite
#  is the weves
#  f
#  ----
# iter 13300, loss: 55.651085
# ----
#  t hat fiansry was
#  sing.
#  "Whesmaze ancare yeatr gone thes," Thiat the fothinen ;oouch bimed is ou to selon cale er bin
#  srerirs,urtt cestimly. Imes and we snortery, anm ma cabr.
# ."
#
#
#  Me that ef gly
#  ----
# iter 13400, loss: 55.708511
# ----
#   round. Nurd whad net ethryendisingien ponn, ase wat 'ce an the an lobe was nips necort was het daye steed guoJ ills om sfnawy. I and tuld poray and. The sorer senly whand weep thediwto-mintost thigt
#  ----
# iter 13500, loss: 55.872869
# ----
#  thes aphtsides. I thas9 he ontemexd agle. is te
#  r.
#  Heases in.
#
#  Yairt wy anw I ra serlof a
#  nit, cash bowh ined dtonent of I hactrise sredofrisgonbishace lestroneirm at to of of tlicled haass wacily
#  ----
# iter 13600, loss: 55.841381
# ----
#   The bethen
# "; "Lack thex.
#  mus snas."
#
#
#  "The thiser," the siag 'nr ltareyed pomernig,-lote turin bpiof I ghind
#  mamarotanmer and I af was sasdo moch I
#  tuestien oftte meit sson. you. Tamy thaze stue
#  ----
# iter 13700, loss: 55.937598
# ----
#   beanengid ertigl crardigh Is ang yof omery-bCever, wong.
#  I volu halm ned-unchmin srathess Jighe fifen apsed, wofropom the hy thes wered ing a apumers heme fhe toungary croas it. If fas lrame, timocl
#  ----
# iter 13800, loss: 55.928924
# ----
#  or wyof yound to the mee te sou hol in tppons nour lKis I dorwo bad blie! sby iwt ofis as ants incerd wat I high and hin that op of bad woon inery bed s and bhist.. "I treand s. Wion, mustars Cothnt a
#  ----
# iter 13900, loss: 55.820382
# ----
#   ain itts, wack dogh
#  6upfelnoghecald
#  ave is dirt acs cath grathaint bat igus the ayd nid whow, dous tboun'.
#  n acpice s a
#  te ang my an at meen ftors "I angt
#  nole Bald
#  asd n noly the sor. I wearde
#  ----
# iter 14000, loss: 55.666374
# ----
#  h, tf ate aLe ritus the noble ouss,
#  icr. "Hires, mal
#  the muel, pime meeses houts helonssedse .
#  "Nak ar ra nhe gle har-un doofs.
#  "I atts
#  rous whef striof stou the mF ergelstimge hercas witheded en
#  ----
# iter 14100, loss: 55.697900
# ----
#  ataes tourets gind, ho the rouk hone stonmest or mand yid a hgrion heen the pieckate ror lhely the thaco ack. sonrily monmies "ore wipremmert in the k oftuld bamiesse reeg beon nee cwevadstain thac.
#
#
#  ----
# iter 14200, loss: 55.630080
# ----
#  l to wuan the ong cuas, buwt
#  whe plof a]cen ittish I toed waip the wace.""
#  Of whim to ppyeat tolsindiplvapunas were nelk houss axlon, donthed hoDd-ated Hom. Wo on gury millort eived teeg ibe elloots
#  ----
# iter 14300, loss: 55.547008
# ----
#  pouln cibgingmas tolsead caserewh teriscoallantom begeges uft Tat iprsfcangaciraots which
# ebnimed agteachtratothgpale hag owiytingrribt. I here, ,ive, to dord 'n eapp rte wastin" Thavd her fopsex hint
#  ----
# iter 14400, loss: 55.623411
# ----
#  "Thike?"
#
#
#
#  "uby," "Yall. Ther. The ourd.dyapliig. "I and, food ice thet doustlad is
#  ing Sand?" gherdere me Steen and inc urmere m msirgincement ullcas save we heapave gomeno fore intanen, may'sg?"
#
#  ----
# iter 14500, loss: 55.667453
# ----
#  the ang ne intesr'tu as baver berred bkond-ucot a-lontt wert houn nary is eme thin At
#  and ying doun aln, and vat Bwak tow comeen ontein'n an, he?"
#  am, of thecd rout the pownel
#  opcout beedser, wat t
#  ----
# iter 14600, loss: 55.715028
# ----
#  g therad£s fatt whete et tho
#
#  ce-hanorly,
#  a! I mas limeat oulm."
#
#  It gi, to tisroult," un gome and, the acpeon shionsatk  meowt. Barkay hitf'msty yof sout," Loble grags if it he wat canterly gherd
#  ----
# iter 14700, loss: 55.607521
# ----
#  k." ns hemonto we' prliadgl ther tous saoped karme, wi
#
#  wacl them sith ane Shermeme muas ushed the one the lo tho bites hold
#  the soons the enray hine. Whole and caspbisarice we wand of wenet Hisek i
#  ----
# iter 14800, loss: 55.574254
# ----
#  ry in mowe agathetp che
#  ined whtpimeed-lrroug, and cutere ruchang beret Mo
#  Bave waSs at ack ihy."
#
#
#  "I gotesu to he cheef. Shindy-once the resed thad fcrolresf lid the el folvees
#  ovictol ind the w
#  ----
# iter 14900, loss: 55.622728
# ----
#  a' ro ilr. "sou were lemeterot iplroath Heirseden youe,
#  of q
#  postey the linne and fee bucked
#  is.
#
#  "Wer nafgy thindrass Makaud Cof tardas ape er is, as-hist ulverest, cale ach shing. Shas ang eok t
#  ----
# iter 15000, loss: 55.680274
# ----
#   ounderes buspowh Donn's intursernw is. ang andece abllind uturle, Andive diminf and anr erceen ees. Assive hatelf ofkly faind the sinPreth were. mitfouy, ither the hacios our. I dirgoney ral fea, at
#  ----
# iter 15100, loss: 55.960036
# ----
#  ape ir  lorin malpere-wer, thack."
#  "fovo In icd,s pa seleove rowjy at donto brobils, iveed od -reut
#  ers. Imimed and in'. Ibn novee?"
#  Hed eblos pust-ppos to where, win aky as thald cupreing uw ullis
#  ----
# iter 15200, loss: 56.005570
# ----
#  ame wher, ees and, strare fontt labln eon the uheds ou indow. It, a kay heis
#
#  ks hery ivin by -lurqra hass, pagbiner I ore by fame. He-hen he es siun the en whid Shay rore and suls the l at wheyoun."
#  ----
# iter 15300, loss: 55.978730
# ----
#  walh oNer; wamo as toxild theys of ssid. Thare ris ho marny of Iror the the roude proble ank is wathluve hot hat and kSyet Brifello sace. Is an wstt fann I no the tularhsuse! is sheiche te cherock
#  da
#  ----
# iter 15400, loss: 55.793563
# ----
#  ert wennizry. Ime to guug suavete ugl mes. wadent issen!"
# s Shat wor. Shat on, tod batlothed any this yourk tee ineas olraf lhas
#  " whome trend opt. Ioet to lo"uspeand wortut the barthound ghand. Is
#
#  ----
# iter 15500, loss: 55.666639
# ----
#   renoafrere
#  found the stoc
# e gonsarme the to beparalthis I lich ind," "ourvintyulcite of Smate frened.y
#  "herungin, fin oCe with he ou holcy,uind sunger bet so sas wis nealvey.
# e I bees at thik?" is
#  ----
# iter 15600, loss: 55.790572
# ----
#  d
#  theed asd. IIto crat hick or ap and foluch 1rousF in meubishal, Jimu lo cofe
#  mes
#  mish rasar."
#
#
#
#
#  werkond, weritichess is ach. If favas noled. Hy ovhitC. Vel, int wulr, unkis me ofdiss pond
#  wag
#  ----
# iter 15700, loss: 55.687273
# ----
#  hars bo™d d srolosimlicher in us hivict. A Barf thad foove er ick of eut wave of palh at. I wbod lurhess than?"
#
#
#  Yoor. As puing a a
#  impis me. soon of, had oo of hipimeen, thes boo At
#  bictt ghen oK
#  ----
# iter 15800, loss: 55.523274
# ----
#  Sho figlane mopnand sur, Cads oThe stout, thin be an hes, doShint, srme he woun cutreis, hy oftre nen boal om, "urtlerene."
#
#  "Whe to shar reenzl tuse fhe as ceo couvpoln axleng rous thit pos tho woun
#  ----
# iter 15900, loss: 55.329323
# ----
#   and tastt pcalnthe, in coathe ne upe ston tis om is nhachede and wours."
#
#  Houll as sia frocmsochagl.
#
#  "Valmet bovir dicet. A can. Thace simelyy bon yoalp hellleno ese sme soy of ok hat to Iln as so
#  ----
# iter 16000, loss: 55.407884
# ----
#  lerot
#  titef. A-pernilr me. Ay ree come ate bat
#  ment os and a fade aly tach. I and cica blrenill and guee bok reeed the er daveet thaikel of
#  k uivee the dous a covh. I vat
#  the dools. Boml in wevo h
#  ----
# iter 16100, loss: 55.312555
# ----
#  no beow wher fhe oy bxowsenlaive on whe sord,""
#  "Ah his cer houlp to jon
#  sis, Wild owht as of ubire S the owo fich biculy hous croanire stoin
#  apeand
#  Lay wing lo hort rom
#  at hone's the beicurd yli
#  ----
# iter 16200, loss: 55.268321
# ----
#  foons of hebe kash, catunno, taldenis wind stmo. ing toun. He "I cing would the shit the d. "I won elu theut.
#  "A thar. "Ooch wimed, Hontard amf, if sare sfat lisnome dabpat the find whin, Jons, sorl
#  ----
# iter 16300, loss: 55.182393
# ----
#  e, ap delugh, Mat, 'rbetheffiss arrouple. He on cret. efeand 'that distre cand the ulach we eloug mam. Yow of te parcfif rre it, micere stisat up whin mato." Ig nave my ke of all rool loundblorst."
#  "
#  ----
# iter 16400, loss: 55.232938
# ----
#  ugs torolr hanether, fed mandand tureafeed a wobas and, arsme in oun the andpall exreuron ssivill tiany nf rin an ne heon ster memideivog feot tatt a be ind,-y somunez.g masland our or whabicett fiift
#  ----
# iter 16500, loss: 55.137593
# ----
#  ck glin mponeys. Theusto bethin. I bingivepor.
#  Siver anp
#  uline drars. Of hish azkeulc, my shead?"."
# :"
#  It, ant uod
#  calk ther with b ang and yellume Ho a hich Stinn oy ate hesjivichazang, bat'sn. Y
#  ----
# iter 16600, loss: 55.030676
# ----
#  t merfow wiokt; nave was fincem pish Preud edind on, hadytole by berdole one
#  hat soa a he hoclmy
#  wiwhay "The
#  whom bae wered what shat heing mall
#  the, dore the dathanthacly there arice ne my cese m
#  ----
# iter 16700, loss: 55.053684
# ----
#  of ook ser of Poinpin hat tes ulcace
#  bate of mouchrve wy your ginaw tale cighes nin min therer her, a hiid she ke Sishidhiloder
#  a out Shoming fousran seanfiss ar's ole we tais sichind thr wheaf wat
#
#  ----
# iter 16800, loss: 54.810462
# ----
#   k. Shim ase mach theld asrnaid ou were it weremertsen hid the iglinkugl at haneive bowr wusked."
#
#  "eiped prroala angiche did witerden ster, a pa the heas here aker
#  wemked fammeed th tveyte handcire
#  ----
# iter 16900, loss: 54.838227
# ----
#    bo tiis of wis buny wirverefsseze s nnill ind iid, cuwent dad wat tulm sailgint a then solre vaclome lizes didelangich ark."
#
#
#  An the theud.""
#
#  "xelyediaf weams sharraror Noing
#  rat
#  he darkouselm
#  ----
# iter 17000, loss: 54.750126
# ----
#  staroth wageatr murd and scan?"
#  "of bot oar, asy domeainger. Whoucsirf ingly," "I ele ibl as q ice still in uchteve the sy of brve ittind?"
#  "Af hat Si
# ce wat rexhaidee thimel," 's in thangiaed wer f
#  ----
# iter 17100, loss: 54.646329
# ----
#   was cheen I in hithe ly osed-lublesont waru is Iun."Wels, mup ay
#  ult "ow b
#  band?" and a the how waduld meslireme buthe wut,
#  wo eadd the ind wo to yo lifigs kire hesh I cr fif's lat din-poniund cuo
#  ----
# iter 17200, loss: 54.754483
# ----
#  f rained y'thair cecertise," oThousy hin led'th uletire to wan Sherl she conish may, nom coaon kt nomt. oked dind he. ""
#  "Mle soly and teon tuixley hous Sasebthe nak rime, pad b pad. Waldes sasey, su
#  ----
# iter 17300, loss: 54.664652
# ----
#  Me shacg,
# sslyat afktich sey yous wovat tharow
#  to eegha" is wyows
#  in!"
#  uuntriy semes the savedechish whavo the
#  prse none, when verd bs wempeulde, din. Toad-d," I dove enm thare than we I tecond!"
#
#  ----
# iter 17400, loss: 54.534884
# ----
#  hauxt me, folk.
#
#  Them naste mas wizeb awsore ot were, ersy yor war ang fabegean this sher quny bupure aen wued soothilde, wat on pued thritiard co than lrsant. Gon he? Hat
#  bis rade
#  of
#  lacly
#  Itsos
#  ----
# iter 17500, loss: 54.580699
# ----
#   hay ook gurd doun r of thed fonr abet te
#  sofes the in hak wereracone
#  gyir onter I has ner deen ored care ther aze in, as an, parcselly grole Fuwd whas owed in b cais to tiod thaif stis no vit to ou
#  ----
# iter 17600, loss: 54.522579
# ----
#   chathinfe, insent."
#
#  "ay darof as tuligply come Arhan hald for ering prouten, of
#  quwlonaop in.y
#  "Ssus ap lnat kis of thag the prea cathey Ite iy coed seouit Mlengrot' badex. The
#  houl ."
#
#  sook Ma
#  ----
# iter 17700, loss: 54.460004
# ----
#  ut to there cokn if of fee the stiip sore. go and and, wung ouned nor. Jancare me s ay ther desnithind and mand She fome,
#  wharisht le
# . I heon hast mund have the th tharower my and hove ert oow
#  wat
#  ----
# iter 17800, loss: 54.227168
# ----
#   lithed a gaid miser where band as, hade iugh shay we there Leat ner itt uno so tho sook st, in the lee dits thoud.
#
#
#  "We the rede KA. Wh the "'s hous a to meriven dealr the hopughourd burd mand ghic
#  ----
# iter 17900, loss: 54.029739
# ----
#  rovert in be my whit
#  seat amre xos heabce one I allying meanok he mehsry, ceach l ireen, I me wersabr
#  lat wertay."
#
#  "No domener feaght the alnoser nerd moft clang the of fouer entheftle this jeitti
#  ----
# iter 18000, loss: 53.962318
# ----
#  -s thand a eiin, to mebn
#  lort br in Bish thare
# er pome agkise, becr rreeld une, and fiwh of cuak rort whit Fow hat losed hane tod gulvelly inly, b iug
# d wo was to megen the a hat tu foat ligpes helll
#  ----
# iter 18100, loss: 53.964143
# ----
#   footheaf lack kemy, urtts meve
#  d anet, a and of kn, l't baso mas. W& han,ray mand in's wangay hom the mongiegall I hich has, a maind tie manler in ho boade, a yice th ousk lavlters." I amle harly th
#  ----
# iter 18200, loss: 53.853676
# ----
#  o warhemethed the the the at jengernd an lowh tiy. "Thas frouth work bet and halfrteshile a
#  souch of soreednulcE ot hat--nin fourd. "Wandibcenlt," wat
#  te an wat I lxesweM, has a the Cuwky'g-lat mead
#  ----
# iter 18300, loss: 53.776627
# ----
#  urotp trrou, sbicton fortes, that youst in, one werd whith whik and sadey uf pass ofliter wow how sead be I inwt yaiduld and the sith nore sare the is,uann yound
#  the whereon mere alor anelide a hade
#  ----
# iter 18400, loss: 53.756684
# ----
#  nakion theote hancann my avhecere enm bast, oned beasn the mtarcireth th the
#  anllonill, meadr his the wi. your te ste
#  iming pads wabpatr ttot wouldg yook caoverr a. Thond intiyt, gold culed
#  owemid,
#  ----
# iter 18500, loss: 53.656558
# ----
#  ha hero is puno, acked Mbavid a my. At arsay- hade tor at stiin telf wich ceves denteing as, heere ap parisady
#  Hourd wis my ore stoed mesh tecerss, in. Thakrno had
#  ne ou doush val the I a favat wat
#  ----
# iter 18600, loss: 53.688263
# ----
#  r at hebw'cw. I wind theid
#  it houl. Bat, at he and fale were stoll
#  nwe Gathirer ceade hakl
#  "' the
#  whilly
#  dof is mash one one can kerst and
#  momesimeenay bunt, lny
#  wang ab inryer cose his om Aid
#  ----
# iter 18700, loss: 53.700739
# ----
#  tolads.
#
#
#  He
#  wo grath to a sto oxlland thove raid ow whe g whees dous wered ow, abs mo thimwipd no so to paw: thilld har ele the maat ne, mugh, wimouflantle tor to
#  tpracjounl s
#  wy dey heroste gast
#  ----
# iter 18800, loss: 53.714814
# ----
#  ntale foneg," mat
#  oo of tou trons warst sangenithe ined thed theined thaiver, bu hat haceivve wasm the bat
#  we wand, ot me the is tis the achis, be fot the hendiyo bapzeed minm unn theaplett. Shan fo
#  ----
# iter 18900, loss: 53.636742
# ----
#   some bomeet a 'st hand dode se for,d larvitut thave it tho mist ove whelcuy, yilr bemen the andild owe ned wave wo thrafly
#  weo  qust, I a ghatt for and owr seld to hald
#  Jube sto of of it with to al
#  ----
# iter 19000, loss: 53.529194
# ----
#   hag har toime way wa fin to Siy the,, ryom age the rank maplittar
#  opivasen butildsolsep, avy han, hiwp alde aTpwis.
#  mit. Thave Ar.
# ut sutra and pis. It den am thaplege 'ne wole sowtoul yoas wis he
#  ----
# iter 19100, loss: 53.447495
# ----
#  urt
#  puge oe owh
#  tallded won if. That whoust wacr wogs abe s. He at couck I van same wand. "Iln band otharlust no ont I mpont I Hat ackt one She: vers ich owt lo urpgout tlintuyed
#  ou coued. 8's shor
#  ----
# iter 19200, loss: 53.393674
# ----
#  ianTas miar, u lomer,
#  Hopake to the have owed cepo tey deakd, yoo ly
#  bats fou fit,' whor hewl'"
#
#  "'
#
#  "Or futh th
#  ullaiegos ortressmee h ot noulnt uned winga cadsepe pase a vave comn my yead tr. I
#  ----
# iter 19300, loss: 54.063948
# ----
#  ougk infal, llraad reamach to tiy olse whathoun ee heryy cl;'s
#  deghien he lolcelighadl sichelr as hat wach hab hich a to mon it mim bonoth the woulde Sfcomyen I und that reep was lerto gate ofsirelu
#  ----
# iter 19400, loss: 54.345215
# ----
#  ma he and a I hat lis cot. Tolarde ar sos ferideln anded tee fous matled ald wius
#  dewr. I'k
#  peas, neld nath there!H?""
#
#  'Yow
#  habe.
#  ""
#  Ho wacd porle be olntow yout fic ofasiley, nowt ald heid, in
#  ----
# iter 19500, loss: 54.371998
# ----
#   teed tiyowet iviimerere moulr aid uther inf
#  as he ofaight touvo ang," stot
#
# , I It-ber, his ave no fouct fath drwim of he malon the hark hise, thithded, I ur. The haken cins tloulm foufden barderpee
#  ----
# iter 19600, loss: 54.351642
# ----
#  n ou lousreprowt in wared whe of
#  to wored bus ardroye ogys wat iedeln
#  mentis one bage,
#  isarad and of copre weus Shik the luter and fort ufts sooId then
#  us fid det no Mas of his was onke and creot
#
#  ----
# ...
#
#
#  I
#  I with what?" His mextidg he herle?"
#  I onenton, suses, and be ballioked stlangls, panged the fartoly that shomany wagis, it. He revion the af in a pat lasks Moplay," ss the mony busting
#  th
#  ----
# iter 153600, loss: 48.680350
# ----
#  dinening badnide arionengeanfinte for ar oler,
#  sher
#  whigh poped had. It coutterven the, pock She thene it me's demont est. "Word been be Firdeparye, silly ledo-s
#  sil whfaoges seve the betting dord
#  ----
# iter 153700, loss: 48.739394
# ----
#  s in verying is. I
#  nom wowe of this for hes of fimicuruare buged."
#
#  "Anded quay wuln the
#  pear wzop I spre wittoncy. At tray. I
#  es trark criktprancmated of it at the saver!"
#
#
#
#  Thand triecr at hav
#  ----
# iter 153800, loss: 48.630121
# ----
#  encoon the which san tridinding had on, he was to as uh her matatid, yewer fiotw puld
#  were se, I my Goot," sit to lenons, 'tr the inbaninirncever. Thend the ving at deby hat sery hadde surile snond.
#  ----
# iter 153900, loss: 48.582111
# ----
#   crorain to en trien
#  ored
#  Hare of aly-empece lestided be
#  youre
#  wit,
#
#  boce you witains, himme ro? Stow and kasts wowhy up yousr were is wingy onet soon I lefting be the
#  homes cllivg praiber us.
#
#  ----
# iter 154000, loss: 48.522812
# ----
#  hs,
#  acsuat yuar
#  ocr
#  the tok, botl ssood to fore to theer
# , sted, of peawe, as
#  tule exous ence forngulor. "Pfiever, hobp care therr, anlo?
#  " "A! siderle the; shend ba rebet are indlo have thin tre
#  ----
# iter 154100, loss: 48.523007
# ----
#  n upltest the
#  Hopred af, sulrigu, non!"
#  "
#  stray the were sconthirss wy dequcled porded of the ghiser a to dan sellow."
#
#  There mupon, I qust had ase weslorjeff who will and
#  aged alr now," sour spe
#  ----
# iter 154200, loss: 48.375877
# ----
#  ol ringion and us in be-revary jowt aw
#  a thit wadked
#  for tiker sitce you the nuppay hop? I, I
#  and the omce pook and tqut, at Eulded, in, bed earl iwn, his himsous-.M-mooce
#  as
#  lald it I
#  utsarted
#  ----
# iter 154300, loss: 48.261720
# ----
#  hakn the mowntet the ranmead whicaly been wroidaf the woomEd ams wor
#  the rath stoutt wamy is forelanids
#  maid wand om
#  hom.
#
#  The cayinon of the of frien who adses. Yesf ied down nomDeqked witednign
#  ----
# iter 154400, loss: 48.266894
# ----
#  sperg im
#  that hol thinty we it
#  inding, that we en. My coun it tha!" Your wifhiwn the wheesn deined and once hat und sf le greuff hat they for, that my sssar? Andt her baibellort yhank in inver.s Goy
#  ----
# iter 154500, loss: 48.226801
# ----
#  earcess
#  it hogseach bully, who horen she migned, and and, ichslentr in we reile port paing. Is him arted get phertarnoye abs; Viss, ale sal?
#  I hverl come nowich beneachqont the dare his of Araln to
#  ----
# iter 154600, loss: 48.430477
# ----
#  r, pleend the
#  ginen thould,
#  recure dosken?"
#
#  "Ife as thous. Lerleguspleet kid has youlated the ristone empace at mlaod, trold day aged hadk the verd plistivelale ast lise the made arnesnat to cocle
#  ----
# iter 154700, loss: 48.317660
# ----
#  et wan iniing for loutiugl' Wo "eve his of butt o, Sir,
#  mencaeace nott the mands aglinimatishy han, alleght, it oven?"
#
#  "Ithadding whear if ces, a the fasse. Hell thatser her
#  my all
#  fead ousted ru
#  ----
# iter 154800, loss: 48.533338
# ----
#   who ped, we me
#  or
#  mace one say reaped."
#
#  Aw the hery st comcl the winds
#  oledibsoOl I hersesed tr then."
#
#  "Of comsones, of the lepreser.
#
#  "Oaghly, and the has this whing was theyowt he lefided s
#  ----
# iter 154900, loss: 48.702162
# ----
#  ady rett and stoun I whough. Sevenothelt herreyevered. There futhriep?
#  "Dould usmessesce stost she noosent the l wood bedly in that ther-"Thry seild, and has wabblacked bimcsang? I to a hand it at of
#  ----
# iter 155000, loss: 48.710903
# ----
#   to iningn wit
#  d we noch pler."
#
#  "Ned att, Roound geach weck the
#  for wolme the many
#  a
#  my my oun
#  usdly shot mistarner a st ould and the noped have hould
#  beer rome
#  stiterdowur commery.
#
#  "If she
#  ----
# iter 155100, loss: 48.619907
# ----
#  " Doles upod. grawlers you ating hewins hach he lion, holly trated gout wink
#  thad pellet. It come dos the purded. We for hesher murnare wive may bublugureever hacandow bathly seesh tonter a stern fac
#  ----
# iter 155200, loss: 48.810989
# ----
#  collowid-forey thick;
#  I wat oples. Lestt the we me fils dicay gbairen thin to us anril, and nen.
#
#
#
#  "Somay. I yor
#  sway s.
#
#  Sker the stank and beecheon's rompoul the winting land's it
#  of
#  I was ni
#  ----
# iter 155300, loss: 48.885472
# ----
#   evow, the eloncarked-lucce at!"
#
#  "I of add rithing
#  upon?"
#
#  "I is do olverde
#  ly wack, workess of evcre see spary, but sil utonde, with afness, in catmondy all the reflay hill the stain
#  ungin and
#
#  ----
# iter 155400, loss: 48.815603
# ----
#  ere from
#  has in it meveson: Nod are you fors troing teine as the byiegly
#  beat proughel the has reingetevice noved, hall. Or thiplinI
#  cever of to cailsen where sil, to of to whorce houm; a onen o'K
#  ----
# iter 155500, loss: 48.733549
# ----
#  nt is
#  ham at the ong, ven our wacremang astw to or ox I hop tranduuch. I
#  diteed upekhtine avest. "I leathen, sicoret dath the sulo I is expane miding ine ems be fawner mried at and of he or formes t
#  ----
# iter 155600, loss: 48.572768
# ----
#  aiver, asty the raothef uck, stanver he bomas
#  dist alve it where olentirets what I cactove's is usure sil it gowlindlist hached ening that ay; me dod uns the."
#
#  "
#
#  Read shem her."
#  B fronkens, virh
#  ----
# iter 155700, loss: 48.625375
# ----
#   on
#  in op, and a (and of for,
#  you wit a couthssed wit oundon wook onteed ucma so that,
#  was welp-under. Hisent a somonon lanst,  tinmot with
#  I migith wery
#  the lays nut and sfaty the crall and clan
#  ----
# iter 155800, loss: 48.649707
# ----
#  adreatt hand the his at smang ing atpem puseyecton mad that and bulgecp the hraolless, that't us pane, of thine, is is nofrlomy ate
#  that them ups gived besce offlimartied with be o, I
#  sare ink and a
#  ----
# iter 155900, loss: 48.595590
# ----
#  t hee wall anblarkaub
#  the
#  it ille fruly loous this wutatings iw thon and ther thuckint hishy's arolers," mige. In bived ip trood anceitt ocl ands and
#  the station, gocken the sone! He you! hand
#
#  no
#  ----
# iter 156000, loss: 48.501922
# ----
#  shals ind hove elngert so
#  so-ne oved. She bitt a my a qu'ped, I a nowf the oned the
#  Aglated to there to store molluon your, I stoda
#  burrirs to my beaven trule layk, mut nef ars frisfserpong a's sta
#  ----
# iter 156100, loss: 48.383012
# ----
#   suy resmalour heady foo sedentsuge wrimise-were
#  folver is whouh wromse rivgintor, whace," same arme soxt bfeath of 'the?"
#  Open wouch the and frur, and a thes was to mataparates so fanow amasadr whi
#  ----
# iter 156200, loss: 48.374579
# ----
#  at I giagly, thon, and butlk Splo maelre indem ul wo and neversing is
#  maccos a
#  dotre and inter thand the wave or the ondenladtish bomstlied, rit chat unge dess," sichen of winmed cematated I the way
#  ----
# iter 156300, loss: 48.560097
# ----
#  as have tfille to fou; damald will't me bersedel rreethice, in for have know a duld
#
#  was the
#  golma this the mong loing, was en, your inanf we mand a grle, as meaclethtilved thore at thake and the fa
#  ----
# iter 156400, loss: 48.385276
# ----
#  'fittiger upcome had comesnly stertenter of shatedry aosed lady hal, watysing it scanh himoned oven bler have have trersictanct anmiroodsato hole troiteed, but or or par tray, ance wat a
#  my. Ande hon
#  ----
# iter 156500, loss: 48.461838
# ----
#   closken of's tow his be tour I he pread sa
#  was
#  brepent a buge gilldon that this my and tligiled naked e the will fromed you ef, ling by on-lelf, but I vion a ald the nould and for sovinitlen a sowe
#  ----
# iter 156600, loss: 48.715173
# ----
#  ou heverser hall worke os thadreat to lestest-spow llong I be and polt is ere the beke whicht.
#  He wiple betlly my fore for lethen mit'l imsseno
#  wewr, atsullo and I seititaly ofter suse, 'usrest ther
#  ----
# iter 156700, loss: 48.695690
# ----
#
#  I man, I bor hery ond faavin throut um steriten's them what youls."
#
#  said.
#
#  "Igenn
#  chour pcersiring that paivalyGent anven, in goreribl and
#  this the sao fuw and the caxt, ask, than orrtesson had
#  ----
# iter 156800, loss: 48.960757
# ----
#  entand you with memping them matt, Wasted the have at-evere amow that my is we reissesting aly is vere
#  ats noan, he co what the fortery clock lead it which cen foriturcaupteen quintry frack, is be wa
#  ----
# iter 156900, loss: 49.114789
# ----
#  gher ren the carnous the aen," Hid other reast and is shollkentaty knoch the al finyce
#  me halk. And and ouct a protped layole the niss,  1ffearntill? And mataore I was the weseed to giserseve the cou
#  ----
# iter 157000, loss: 49.221468
# ----
#  ded, I carcont."
#
#  Bead in thach whis Bited ingale the ronon betset and had morme sole of her herrien everred,
#  Code pirs.'
#
#  "What thit in the maow," in.' Ancent," such therlaveressirinion
#  a she be
#  ----
# iter 157100, loss: 49.192538
# ----
#  , insied al found the oppon of at u seviss mand and itlicusack she mistly of capre striind," I he is but anoo deachted sCaid noth lister of he fralled troughond theo scone was to for, my upsing, head
#  ----
# iter 157200, loss: 49.090278
# ----
#  cand apgaire rere and mors gably. Mysing thed the
#  ugly nond yur thes onsais parked thim, hab is or beant."
#
#  ""She, ve sm fart
#  ou campantiem. "Nut whokso.
#
#  "As
#  bluar it for wowl, coum?
#  Supen."
#
#
#  ----
# iter 157300, loss: 48.944169
# ----
#   sulee, and whalled the
#  ofted of man for has ourver, loom. No-. Nenger
#  reuld tremood the blist, in cilled Hise If to wercugent at gatenor and is my in ill the uwe goctrent yous. It to  'Oyes ha was
#  ----
# iter 157400, loss: 48.962679
# ----
#  ed reen a centiotse, pranter." she mluxt. "YourdieÂd, in. Whikl Me wetter thery I knomer
#  oul of tan this rondgoned was have, suce you fore akoo,
#  as wify the yor bething Ssard, in casken."
#
#  Hincains
#  ----
# iter 157500, loss: 48.747498
# ----
#  arely the portscousece of of coth, giane had sume tolmes in seint
#  as turist red the traidere hole the packecpidvabicplanke aritt, I he the, It pliastentitt in
#  Risome."
#
#  "'hat the puininges ased pry
#  ----
# iter 157600, loss: 48.721078
# ----
#  irgeshenfnon to wett
#  chall as
#  inguing Soult a chard is Hards askin, is ether.""
#  "Of of hevernin thas he cerdend. It Âlernould shis to Prow youple crome. Might inughtor, pise a galberier."
#
#  "Wait h
#  ----
# iter 157700, loss: 48.870676
# ----
#  iss al, witt the
#  bestious thas not axqued this dristing my baicain daik bo as, it ay
#  tixlescure! quped I shaked itrion wat to that yas pet,
#  in and simswlilm. Buted gict and cappeat top More deeng,
#  ----
# iter 157800, loss: 48.887048
# ----
#  Have in
#  this the reyire foom wMy, and bestido."
#
#  "The
#  wary."
#
#  "Yen can
#  ul fry yould bugyon eave and it uid. "'They butm of up the ssate, timanting coqued bight and "Compug was naths-hat. It ien t
#  ----
# iter 157900, loss: 48.870235
# ----
#  whor ne councting taksus neces."
#
#  "Thea lainf astnnt whouch a
#  makon time
#  cenongect--senweng gl Fark cwray dan the emon corave the wadd the youred coushre us, which of and doure and that my
# adil maw
#  ----
# iter 158000, loss: 48.924151
# ----
#  id! atee."
#
#  "Aeinten."
#
#  Nisuln that- atse homoss und bane was
#  had her."
#
#  "Oo Oebly."
#
#  "7he up gacusurd--a clang aSed dens me hald, we thar yout cauwter to sieinen uw had a shole weithy. Su gacked
#  ----
# iter 158100, loss: 48.788694
# ----
#  m arke and thond
#  luset asse lartCelz! Mn parthing the
#  stion ingacce founees.
#  quid tets reploppry lo butter. an seepen anks" a thtting cherpisususg.
#  yoush was proon then bearopricertal St. she com
#  ----
# iter 158200, loss: 48.683825
# ----
#  e ther in the wand, in
#  lest hid a
#  Stanoey nes reyut ase didaim brain, exped up Victer aived-spot
#  counely," oud eching, think, sham that I wave colmes, anver, was shant ethtes efrinank
#
#  qupateved,
#  ----
# iter 158300, loss: 48.629780
# ----
#  w fumexcang
#  in to wremall fered aw mofing dise was selal ouper to hem congiedly that,
#  to as of prand so rerers. He shand ing bape for havely, mo wer uppleding and in abwin verkent be simrow, to ciat
#  ----
# iter 158400, loss: 48.834608
# ----
#  ntellust.
#  sading wn. Nademed of able the niniotling hive ocl Frourfil porst worald situlf can you in my a cous siisell mi?" Surtirnt to Well agss.
#
#  "The sive holrole alloms," Qumed the furs. The ha
#  ----
# iter 158500, loss: 48.815633
# ----
#  k the and asthen, k of thewer, and of tresting neme chank the lick the
#  pogtrenown medottire as thoulker, I sondten ald fror.
#  Lapby. Whig her hxreared idered he has my tould my bas ere lamm. You mars
#  ----
# iter 158600, loss: 48.821872
# ----
#   touse, sest skamy frut the siche coplinin frisone myed cows five when towrs. That tor a ssant the mane, asce," sur the exwassamighly lizfernoublough,
#  I be wa the Hold came by thorge all a' streat ag
#  ----
# iter 158700, loss: 48.828985
# ----
#  ght foo that abpsal. And re risloistyisandy com fouch taxt you domling uid, toiks?
#
#
#  I have
#  it
#  seas to
#  he al ip camme are outh somiiniblly could. I onady in Lown uilly dive re very laye his nesce
#  ----
# iter 158800, loss: 48.811954
# ----
#  dy ever."
#
#  "Ans momal ont lid dost of hatsentain reer; or! I knould She ans a s not a ling I of the of vead noshy, whed, shy shave inindersactin."
#
#  "No kninds Cers! 'Drl bpaet be the Hortlish bat
#  m
#  ----
# iter 158900, loss: 48.775246
# ----
#   beaze
#  beentible the rain be reellly rise Mured I bace cod,
#  a shum has datee
#  full-'s seagly an posll. "xrome rood
#  was veraicuary of bel
#  it cint. maty and telp
#  he dom, we at and you the reargab b
#  ----
# iter 159000, loss: 48.605234
# ----
#  ch was sortwed bas batterfirt danging and whata ned hithickerimany--I the, waet is.'
#
#  I etpensiven a lain Geetidhed that not you orn, asongest."
#  be ap a brenes, he
#  heathing, aas.
#  When found upradi
#  ----
# iter 159100, loss: 48.515188
# ----
#  s the rounde cover sim.d My baid whate entirgay. His the you sa powins. Youlchestiriousf over and by mome oney, woom, unce have grist, and to at the furtine me reas
#  chare, trut trore powed to, the wi
#  ----
# iter 159200, loss: 48.230663
# ----
#  peet at his and
#  the to simteb-doupllone, I and. You hat of the kasteng ave facon."
#
#  "Whe Chand
#
#  tesing what you the he soll nollacawits soxilldersuly, for Mr-bout his ming him
#  the mander not hoope
#  ----
# iter 159300, loss: 48.179998
# ----
#  r necterictod and will yoo shing yit from anjulcat to oo Appirtinpile-prain whis inive his have lole Jexy sonas sadkess there that in herce the ine atpess reyageerlitinewanf and!" I rishingsaicer of g
#  ----
# iter 159400, loss: 48.301813
# ----
#   is to surtt
#  have you segervirever my and bat were, bat,
#  I sI from usce. Wateridn, is the pomplay of the re nece carefurd, and shall aco-houceag a
#  have so nach, a sartont,'
#  bitnous wost be had mav
#  ----
# iter 159500, loss: 48.235852
# ----
#  ke of grerers, houghinnaore able amy, rens serdeon drowp nave
#  was maubelysucher noild it maupen inth I was sur, ky weme we in frund and to
#  snere horring so worte brepott forer," wuth have had aed on
#  ----
# iter 159600, loss: 48.062541
# ----
#   "'8whe's me semencessady tiover. I
#  your. "We rifning mumpent upen winks; bighind indey beat expont of she a hil dack, mime gr-yong of is to maps have dack hand to the
#  parly hich, Hovon bat he kapen
#  ----
# iter 159700, loss: 47.916479
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 21
#      18   print ("---- \n %s \n ----" % (txt, ))
#      20 # forward seq_length characters through the net and fetch gradient
# ---> 21 loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      22 smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      23 if n % 100 == 0: print ("iter %d, loss: %f" % (n, smooth_loss)) # print progress
#
# Cell In[8], line 31, in lossFun(inputs, targets, hprev)
#      29 dWhy += np.dot(dy, hs[t].T)
#      30 dby += dy
# ---> 31 dh = np.dot(Why.T, dy) + dhnext # backprop into h
#      32 dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
#      33 dbh += dhraw
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
