# %% [markdown]
# # Minimal character-level, ultra-basic plain vanilla RNN model
#
# This notebook is actually just an annotated, updated-for-Python3 fork of [ONE of several explanatory gists in Torch neural networks, RNN, LSTM](https://gist.github.com/karpathy), specifically [**min-char-rnn.py](https://gist.github.com/karpathy/d4dee566867f8291f086) which worked with Python2 and was written several years ago by [Andrej Karpathy](https://gist.github.com/karpathy) [Twitter@karpathy](https://twitter.com/karpathy).
#
# You will probably want to play with pararmeters or change things in this code or the **input.txt* file to see how it works. Others, like [Jy-Yoon](https://github.com/JY-Yoon) or [Nikhil Barhate](https://github.com/nikhilbarhate99) have worked thru the [original **min-char-rnn.py**](https://gist.github.com/karpathy/d4dee566867f8291f086) and shared their own take of Python3-updated gist of [an RNN implementation using Numpy](https://github.com/JY-Yoon/RNN-Implementation-using-NumPy) or [Char RNN PyTorch](https://github.com/nikhilbarhate99/Char-RNN-PyTorch), respectively. There are obviously plenty more of these out there -- maybe we can't look at them all but it's worth looking at more of these to see how they differ.
#
# Naturally, the [BSD license](https://en.wikipedia.org/wiki/BSD_licenses) of the [original **min-char-rnn.py**](https://gist.github.com/karpathy/d4dee566867f8291f086)  would carry over to this particular .ipynb notebook given the notebook's derivation, but [the choice of that license](https://choosealicense.com/) does not apply to the other files in this repository.

# %%
# This .ipynb notebook was developed using Python 3.9.14 and Numpy 1.23.5; obviously, your milege could vary with other versions.

import numpy as np

# %% [markdown]
# #### NumPy needs to be installed -- could we do this without NumPy or use a different library?
#
# That would take some re-invention involving more than a few wheels ... remember, the NumPy library uses vectorization or takes advantage of SIMD to process multiple data points in a single operational processor instruction and there's [a ton of stuff going on under the NumPy hood](https://numpy.org/doc/stable/reference/index.html). Not only are there a few decades worth of distilled dev effort ... starting even before with the [Matrix Special Interest Group was finally proposed in August, 1995](https://mail.python.org/pipermail/matrix-sig/1995-August/date.html) which led to] NumPy's ancestor, Numeric, and then NumArray and then the NumPy library in 2005 ... so a lot has gone into getting NumPy to this state of efficiency as the fundamental package for scientific computing with Python.
#
# Of course, NumPy continues to be under [VERY active development](https://mail.python.org/archives/list/numpy-discussion@python.org/#most-active) ... which means that the NumPy library is not going to be part of the standard library for a while because the standard library tends to be very stable and there's a lot of work still being done on the NumPy library. In other words, *do NOT expect NumPy using code that ran fine last week or five years to* ***just*** *work.* **NumPy is going to continue to evolve somewhat rapidly** ... the pace of evolution will be partly a matter of the refinements necessary given the volume of computation being done. NumPy is no longer anything like the isolated, almost esoteric work of different researchers and grad students working on *freely extensible* matrix manipulation routines for scientists and engineers. It's not that tools like [GAUSS](https://www.aptech.com/blog/gauss23/?utm_source=homepage) or [Matlab](https://www.mathworks.com/products/matlab.html) are bad tools -- it's mostly that they are not free and open source, thus not *freely extensible* ... you will notice that the early stalwarts in Python development tended to have either .gov or .edu email addresses, because it's just not possible to RAPIDLY get approval for a new software license in a rapidly evolving research environment in academia or government.
#
# Extensibility characterizes Python. It's not just the NumPy library. Extensibility is the characteristic of ALL of Python, all 648,469 developers involved in extending Pytho and certainly ALL [421,533 Python projects intent of getting to a production-stable release](https://pypi.org/search/?q=&o=-zscore&c=Development+Status+%3A%3A+5+-+Production%2FStable).
#
# It's not that the language has evolved over the last several decades ... it is not just still evolving, but evolving faster, and that will continue as the volume of users grows. Who uses and extends Python defines what Python will become ... in a larger sense, Python is a ***recursively*** intelligent hypernetwork ... and, that's WHY, all the way back to Python's roots [high-level, prototyping precursor of ABC](https://en.wikipedia.org/wiki/ABC_(programming_language)) human-understandable *Pythonic* collaborative thinking across multilingual networks defines what Python is. MANY more people using Python now means that many more people are working on extending and developing the language, ie, the extensibility of free, open source development is mainstream, not just .gov or .edu email addresses anymore.
#
# ***The definining attribute of the Python language, especially the NumPy library, is the language's CONSTANT state of improvement.*** It's exciting because everything about Python is constantly getting better and then better and better ... but the flipside is that your old favorite code that you artisanally crafted into a state of comfortable perfection or flawless the last time you used it an hour ago might now be some kind of JUNK based on something that is no longer supported. This is a good reason to thing about keeping up with the latest Python3 dev list discussions in your email reader ... maybe you don't need a separate email account and tweaked email sorter just for dev lists ... but you should understand why things like NumPy or even Python are ***not fixed in stone*** UNLESS you make it that way. This is why performance-optimized AI/HPC software containers, with pre-trained AI models and Jupyter Notebooks orfully-controlled configurations of all software dependencies have become the way that many, eg [NVIDIA's NGC private container registry](https://catalog.ngc.nvidia.com/), prefer sharing their own PRIVATE machine learning demonstrations of how AI or HPC workloads might be accomplished.
#
# The statement `import numpy as np` is deceptively simple and assumes that you understand these things about NumPy and Python ... many do not. Don't take the continued development of NumPy for granted.
#
# ##### The definining attribute of the Python language, especially the NumPy library, is the language's CONSTANT state of improvement.
#
# Of course, we won't need NumPy, right off the bat ... in the immediately following sub-block of code, we use the [`open()` Function](https://docs.python.org/3/library/functions.html#open), which is [built-in in Python3](https://docs.python.org/3/library/functions.html) ... just as [`list()` Function](https://docs.python.org/3/library/functions.html#func-list) and [`set()` Function](https://docs.python.org/3/library/functions.html#func-set) are ... as [`range()` Method](https://docs.python.org/3/library/functions.html#func-range) is, [which is used in code below to process the openen inputs] ... the point here is that the [`range()` Method](https://docs.python.org/3/library/functions.html#func-range) replaced `xrange()` from Python2; xrange() no longer exists in Python3. Python3 was fairly major, backward-incompatible revision. Backward incompatibility was deemed necessary because there were lots of examples of things that really needed to be firmly replaced, for example, Python2's [xrange() is sequence object which evaluates *lazily*](https://stackoverflow.com/questions/94935/what-is-the-difference-between-range-and-xrange-functions-in-python-2-x) ... since range() is ridiculously faster, there's no way or reason to call `xrange` in Python 3.
#
# ***It is perhaps worth delving into the minutia of lower-level just a bit in order to REALLY understand some of the implications of data I/O ... and why such a utilitarian thing is typically built-in or part of the standard library.*** First, we use the [`open()` function](https://docs.python.org/3/library/functions.html#open) ... works with [read() method](https://peps.python.org/pep-3116/), which if unspecified or specified with empty brackets which defaults to the -1 index to start load from the very beginning to take in the whole file text file from start to finish ... we could choose another parameter for read() like 30, 300 or maybe 3,000  ... to ignore the first xxx chars of data ... maybe to debug how out code processes the data differently if we ignore a big part of it.
#
# In Python, a Function like [`open()` function](https://docs.python.org/3/library/functions.html#open) is a block of code that accomplishes a certain task and runs when it is called. We can pass data, known as parameters, into a Function and a Function can return data as well ... A Function inside a class and associated with an object or class is called a Method ... to use a Method, we need to call the Method just like  we use a Function but since Methods are associated with class/object, we would need to use a class/object name and [a dot operator](https://www.askpython.com/python/built-in-methods/dot-notation) to call the Method ... thus the period before the r in `read()` in the `open('input.txt', 'r').read()` call
#
# In addition to the Functions and Methods... you should play around with the [simple text file **input.txt**](input.txt) a bit ... you can and should also play around with the code in the following cells.  It is broken up like this in order to illustrate something about execution, eg the first cells process quickly, but you might want to leave that last cell run for a while to see what happens.

# %%
data = open('input.txt', 'r').read() # input.txt is just a simple plain text file in this folder of this repo, but could be any *.txt file that you want to use
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)

print ("The data in the 'input.txt' file has %d characters -- %2d of those are unique." % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# The data in the 'input.txt' file has 5953 characters -- 82 of those are unique.

# %% [markdown]
# #### What are RNN hyperparameters?
#
# *Don't get excited* ... hyper means over the entire landscape of your model ... hyperparameters are sort of like the rug in the Big Lebowski, they kind of tie the whole room together.
#
# Or, maybe that's a bad metaphor ... but [RNN hyperparameters](https://learning.oreilly.com/beta-search/?q=%22hyperparameters%22%20RNN&type=*) are indeed an exellent starting point for getting a sense of why RNNs are ridiculously effective.

# %%
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %% [markdown]
# #### Wait, what are RNN model parameters?
#
# [RNN model parameters](https://learning.oreilly.com/beta-search/?q=%22model%20parameters%22%20RNN%20%22machine%20learning%22&type=*) would be worthy of some serious reading and study.

# %%
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %% [markdown]
# #### What is a 'loss function'
#
# A ['loss function' in RNNs](https://learning.oreilly.com/beta-search/?q=%22loss%20function%22%20RNN%20%22machine%20learning%22&type=*) is a much larger topic that you probably want to ponder in greater detail ... at minimum, it's worth reading over the [grad loss function compuation suggested by Karpathy](https://cs231n.github.io/neural-networks-case-study/#loss) ... and it would not be a bad idea to peruse the [CS231n course materials in general](https://cs231n.github.io/), especially the [git repo](https://github.com/cs231n/cs231n.github.io/blob/master/rnn.md) and the [CS231n student reports](http://cs231n.stanford.edu/reports.html).

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0

  # first, the forward pass

  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)

# now, the backward pass, to compute gradients going backwards
     
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %% [markdown]
# That's a lot to process ... but we're not through.
#
# ## What function definition comes next?

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %% [markdown]
# #### We're ready to to initialize some of the parameters and start things off!
#
# ***We can see that by the time it runs with this data for 10,000 iterations or so, the loss function is pretty close to being minimized  ... you can see what happens when want to change it up a bit ....

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print ("---- \n %s \n ----" % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print ("iter %d, loss: %f" % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#
# l(.kL6Evt!.;P/24LgAòéRé雲Z2bgip
# 4oVVbj!hs)aò雲xK'ëAwY3ò(q@Qh9WJ-金
# —S
# N/.DWK@eLsI-,ha4meiLxgdrGQ雲5;bE-
# còpp/9DU雲金ëbqfRIJfqLTPZ2f!-金z3sFuTjCiQjgC傳W金9e qH傳t:EexM..f雲'j1—BvLEkpbe
# Jk傳tAJJ'rcdPK,v86pfSGv6BBI
#  ----
# iter 0, loss: 110.167974
# ----
#  ey lrE le/Ciolbybn3Rrf lsc cuIolCcoWf olry alerfilb2Ye et nIrlhl9a
# ocsc crg cbnrgrntc yiaeehers JTtsy2sos  sa
# e crlhO cilhhtydcoi3c cb kloR oee/o1y l yre4Bhc nAake cbe nLabooesotnafolro a ltltom i bc
#  ----
# iter 100, loss: 111.992251
# ----
#   ethec enlkecTeine Wisl bica meeaobneo mn h nyHTnos eis 16iba nhn t ao  optsit lyoaaneyb otaaiho TFmvmo(hwrt ocsno ly 7l enuétel oy t Vyo (7G6(0ë—yl sdn yyce6 lr6a o6(6
# W0como hWotesnezln tc drth6haal
#  ----
# iter 200, loss: 110.013889
# ----
#  l.lgn tfy ,algmdaeloasttbro 1 Mlr uan f y Wels,cee,Me An T.e 7agweaWtnrgle (123136-11)
# Tv Svfmkeasn bo St 0esn jmonn 9leosr w(1WiSYok :WFob bbimi Giunleee (1-22)
# ),t (D,e Jy 1TWet by WaykhudWRk M Frko
#  ----
# iter 300, loss: 107.343387
# ----
#  y ye  uosl by cieiN (109)
# TZto asilnt 2ErGsaFg koc(fin bear,seu Ln Geu Rovs uaglriu (106)
# FgKoseuitusizaloe @G AlasisitmenloA (S.Q2101傳)
# e nsuphen iodoaser Li 1Ma OuvtGgcoa(871J1062)
# bonsnLdciue vi1Mh
#  ----
# iter 400, loss: 103.980364
# ----
#  z ouiurhn Gfiea 5e byet uecoo
# d hx JO-diat. iahnt /tinh ot Shuo Ty 1h金etr aohto,nert Js Amelgeaho an e yinhm tdchme outn a.t -ap Preeerkar 'og mfgt iyrgom a bo futtDf A gprza Nrnt toxt/m yh ouas (6860
#  ----
# iter 500, loss: 100.829726
# ----
#  , Aafia ér金rertro Lnlsthe CxPmf by Ten (112M4)
# Nort Dos Mi Rfgertiov ofalheo by TbyTh byhoenrte Dcare fhëok byalin CiW JArW (1137)
#
# a by Chol Twapeetruothepererenes MentIes banhek ciltes Mfml Smy (17
#
#  ----
# iter 600, loss: 97.622390
# ----
#  2)
# Ansee Fisse Cained by St-tgini  H Kiedley Iothlttdemntu MYltatcisn (62736Or
# The (08656)
# Miiiche Joy bous Jf Whmigecoeqa.enrsenslenpn Thy Inilde Petlanes (83965)
# AnogegKahn —orllle (16725)
# B Wh 3109
#  ----
# iter 700, loss: 94.257957
# ----
#  (66642U
# A:  Gom (221)
# daversel Scacltasf tronm Fi Grels  o翹m bya rms Thesror ouattlas kf (664893)
# The by —mgsler ar by Shnllwarotos Docs by ThmJ te was lsharant Horver (741580)
# 1)
# Womay by omutreaMoso
#  ----
# iter 800, loss: 91.695664
# ----
#  rin (1111)
# Mtthd JoJre Rocve 15195)
# ë (069)hG (1805)
# The PokW (9897)
# Dy KerxOsrari.by .avenan Wonle (701z
# )
# Thi ooirli(by Lure Rrnsur by acgO ondT7doJzens Einsthxeriucen Her-te (R1414)
# Sht (7719)
# Wm J
#  ----
# iter 900, loss: 88.750225
# ----
#  79414122)
# Th
# e Jinhee/t by t. Vef Wet— W.e Rinte Kes z. 6hf by Carue Hf Chelere O ore A Ahe De. Gal oves Hom; Fante ShiGod male Thiive Leltp by Velre by Joale Bomild Le oor Srol. worvmokiaf Seles Amem
#  ----
# iter 1000, loss: 86.476713
# ----
#  oos by Thens ralve Eom DygIwh apelere Kiplelres élries Erlelk9ogé bexcsre (9101)
# y Ef cidedoa by Seoshen Dowiteayless Hetlimerd hiosthy by En (91552)
# LI.inicd Po.sernerkelerdeatarest dalnes Vh crodk (
#  ----
# iter 1100, loss: 83.834841
# ----
#  hcgeEte .uremtos Iigoftan Mi—tereps Trtaoterwastisop yn gaoteg by ioke uechesttPs e: y Wapen by Thing H!leg onk byoleriaaere ain Cand Ash Cafmesl, Gaedo ome berop by oriotoyding Wearlix the Rhot ,oxsi
#  ----
# iter 1200, loss: 81.494326
# ----
#  tmomes Brths by Rioro byomolh or Morph Mpomatuothe Anu Loehk Ehs by Chlphe t Pystes byorlens treas by Hithed Butme Pylewtamasgele oy coret Po:tasdod Pocel (71025)
# Emifale Jor by Romits Thd Eom (15405傳
#  ----
# iter 1300, loss: 79.624513
# ----
#  392)
# y Hr Ouplez ofene ,oTt. oftun by Miniorn (6533)
# A Mroches (72012)
# Asnsby Malete Inn, Sohe Soime Fetham Vascoin Lo021216)
# Prsome Dothas (6339)
# 7cah Hf Brhou a Apris: Corypher Ga-the  Thinosk Funti
#  ----
# iter 1400, loss: 77.405854
# ----
#   (210023)
# Th munlestluat: Stillous Daregtmats Dowrestuering or Rasttoby by Jr Wilke (634136)
# The of The A bof aznges: (372136)
# Milile (133673)
# Panges o tlignlis (618412)
# Rilzanetoty (13524)
# Ceume an S
#  ----
# iter 1500, loss: 75.922314
# ----
#  icn (6t, Arosk Cillilontarued by Fomalvical Koman by Chaleg Jaticion (6341)
# Yeantinln Herstlh odAlolas @arserolecGm Ad of (62913)
# TIA Hedvinraun Gontdano by omchen Doc(viSmayd Porlncg:rttoporofe Duabe
#  ----
# iter 1600, loss: 74.030272
# ----
#   E; Szat ptmibends.et (11197k
# Th Alllic . D. morectereve ansda apephh sprxor of T. are Cla t flost reoeige the f
# Sge thepf thItt at Wide K.o rosx by Jemuheasd Rat
# Omlere fPrpharlfes of The ted anss (
#  ----
# iter 1700, loss: 72.709582
# ----
#  e by Jf Bovlce (19.4327)
# Bby of Ford A(1S
# Lunkr (16123)
# Qentn Ginl, Aici; Coter Domalies Dack by W.ccakys Cank of Hepou by Camé Sadod Hacte byost Cothens Din, Ba W. Fa Liveut Duakanttaldesken (169706)
#  ----
# iter 1800, loss: 71.047736
# ----
#   Mark by an The Momes (7190)
# The Anam (7000)
# Orcsas Som (9440)
# 傳y Sby Sof Duamo Jompens Fraer Dforitid Wi-B in Hn Sereta —  ils St't Walz by Jolale Sof ftores by 921116)
# Showol Oce
# y Molle Sen Anvey
#  ----
# iter 1900, loss: 69.409027
# ----
#  dees an Griiog Harles Drak Stly Grimt (19962)
# The Sheristtm Scem Sfo wiank On Aorkodyil Dochelt (192)
# The jwalehr Crec1le Revkerof Morlale Bapety by gofm by Me Milll Y Sroref by Mhad nat Wayxp (1342)
#
#  ----
# iter 2000, loss: 68.430323
# ----
#  aroun by Fcaro by Was on S7c. (7577)
# @poV be Jenl (1907)
# The thange, by Waloln Toad-us Waxe Wan .irad by Duf thak (8895)
# The ArdVam oungeni-ca Rnxt re Dome (7975)
# The FaQes An Choken bf J. Lale of oor
#  ----
# iter 2100, loss: 67.067097
# ----
#  (8172324)
# Promlepl fesllmme Ehilplres Lero A6傳F.yrenche Wonges trekpan (11881)
# The fanveliilen Foallely (1231317)
# Os Tmomet on Hcok Lets Hverittyl bor of Riglivhey Oles (6654z)
# Tofelgyun by by C. Root
#  ----
# iter 2200, loss: 66.245330
# ----
#  ifs of Outer bby Grthusj Torlpthescari Le of Thy Mine Litten danpor agerteste of Samos Colpaventhes (1528)
# Thid Ilis of Mache atim by Farne of Thalcc (11574)
# Wisheny A. Canxor Gr Tuny by Mlcetinere Bf
#  ----
# iter 2300, loss: 65.013875
# ----
#  l B. c.oline Pyth
# y5tuas Gnictliphel som onthos Loprrareste (62554)
# Des雲miuthestthann by J. af Prictl of crothit.erderbyd by Oletth Scshotharesr vinprer .: thadvenprtotechis livlvendrothsnaPvedelitari
#  ----
# iter 2400, loss: 64.087466
# ----
#  lle (141541)
# Vilars Dars Jolmis radery by Wausaleegse (114740)
# The Wromaple by Joleusgar Eortxadby Qeng Doakenreuvensobe 0(1klars (11413金)
# 傳nseleranTtadina anpearn tharone Peolt (13454)
# The Am bablng:
#  ----
# iter 2500, loss: 63.159702
# ----
#  he byens (6507)
# Tive (6062)
# Neytatise by za,den, Alonerer Shiliobe therond Share (6412)
# The Sciungde JaNkind Crontrira:  S6Ghieu by Fllad Doravl Pf Chatk fenth Swuyle Aret by Apthe Rawesë by Bick by E
#  ----
# iter 2600, loss: 62.006906
# ----
#  Th. Arcthon chicle of Fyle Pofk 1739403)
# Larmes by W. ;y S9513)
# The Havldor als Smen; by Trantery (65420)
# The Gupre Lorlet, Delein an Sickichu; (13120)
# Thu rechus by Mdorins Savesd Iuplerd Wans by Rat
#  ----
# iter 2700, loss: 61.460014
# ----
#  dtr lothe Mit ore Woriley (6290)
# TheTrank Pnictun Wofet (1635)
# Ar ole A Wasre Corens of Arder H. Rops My Cayvs of Fhy Hul—deanp (7911)
# Aricth by clat (9973)
# Unies by Fheis (7209)
# 金Fuxe Have by Jr ard
#  ----
# iter 2800, loss: 60.541173
# ----
#  aliinrler (19361)
# Ohe R.ial Aop (7514!)
# Kamdaun (141596)
# The s. oine tuar. byvarlan
# l Thu Fit. Niwom Moom Shils ë (1474661)
# Lintresse chothem arlha t. Fimpt't id!izpoy byare .iice be Alen The toy Pol-
#  ----
# iter 2900, loss: 60.076846
# ----
#  (8299)
# Masmolg ifc: Woolthos: Thorins (8356)
# A Suer Danget Otink (10459)
# V oteuke (84079)
# The Wine doycilasy by Dewioteves:e by Cher enm by Hreilas Pergevry my Ro(-101)
# The xrerietkes (9289)
# y by Cinn
#  ----
# iter 3000, loss: 59.127451
# ----
#   outlut Sry Zeuglese Fiowon Le Lofgouufe Enan by Huravergins by Jorinarin Thi fe Biiseadery , pengm Heraz by Brersow borthodlensrramiake Txout of tharlom Choa-coby Per oun-th of Dargles by traatu fexa
#  ----
# iter 3100, loss: 58.359036
# ----
#  ntis; by thay Sasios by Beoce by Mroralge If,as Sourisauby Dacmangtet (10892)
# The Cazgs arphang Jaciane (69575)
# The (11122)
#
# Rhaminby by Moskensen do:ding (11325)
# Evan by B. Anzask int Foizgs (16225)
#
#  ----
# iter 3200, loss: 57.895508
# ----
#  uthiss Smothe (1187)
# A Nilaleses (8073)
# Uwopdyend: Cickyshet (8391)
# Thetm V oriat ourgevink Of ots by thar Gnies (6396)
# Jr Fyoar Dise by t.ere by Coris-grarethuan by Thurvsot (6403)
# Wumyin by Horamom
#  ----
# iter 3300, loss: 57.095931
# ----
#  iMding Padges Serte by Rr Vy Baves fxer Berles (8244)
# The ten The Listind an Warlertermer Dinae (81480)
# Senss a Waord Dn Mang Ye Bat; by Alzatr An ererte (121520)
# Mr Ler preustouTe en Wolich on He Gra
#  ----
# iter 3400, loss: 56.793793
# ----
#  Pigrendiccamongocicolap-Lt Dichichersary by M. ilvias (8154)
# Tteple C. Riheveby Londeniby (7817)
# The Ri, y(9056)
# The Blavsecha by A Do Dicky by Jarge cithon bextstpby Fblristhol of Eun (13536)
#
# micpes
#  ----
# iter 3500, loss: 56.099290
# ----
#  tt the Prathe by Chord of Pre
# tisassend am ata s d. /ogctoetesdilgh milalge (17125615)
# Thute ciette frtans by theas on tienssor Mave by: athr os trat@wantdpegtog bost acom Wt tr.
#
# Mas, ing Gt, :x byxt
#  ----
# iter 3600, loss: 55.757174
# ----
#  ovist (9141)
# 36I195)
# O:ce (11cwoR. Mordoviolbens Jorkenc (73718)
# A Of meblassof InicWow anbungby Fmaglstm Wilded is AlStore FyycevedY Afttary by Holdas (60119)
# The The 1meolenturich Fills (94350)
# Ajra
#  ----
# iter 3700, loss: 55.048281
# ----
#  060)
# Perstlom (6041)
# The Prontt of /yd Th BnidriWan (668)
# A Stalesheng Sut wickem by Ahrillise au G46416)
# De Cathus an Wolete (6442)
# E Losdelnd Sanul of Iore (7115)
# Wiin-n KI21076)
# The bainle Beghoy M
#  ----
# iter 3800, loss: 54.364798
# ----
#  egby N Prestst (16183)
# The wnod (1215J)
# Meann (13111)
# Tre Cwylzas Stetitham (89153)
# Thi Dic Somotee tos/lims by .ichlistlas (94195)
# The Anche Coristor ilearlize by Jatte by Jryterteus by M. Meers Dofe
#  ----
# iter 3900, loss: 54.082419
# ----
#  nietmy ofGnton Prarle by Glais (788)
# Thi Wistem Permasepen (7403)
# Sucteriand Dichy (7623)
# Ne Sen by Cho Pemenn an Jonges by aced by M.anlond Colterin-ëyoreintt (9837)
# The bidcanens (7070)
# Alcheone Ear
#  ----
# iter 4000, loss: 53.541610
# ----
#   Llpere Jokrall by Chmara (11087)
# Sra Dochathins Jorelromet mapphing fhopllad W.Ilpoydvernellis (114822)
# Pund Hoxt Bilvevell — Morick an Eow Grerth Wofgolye by Mitht by Jongou Cift ay Haand wilk Mowpl
#  ----
# iter 4100, loss: 53.296877
# ----
#  of astguof Coule Thm Stoyliias Exate Eycetran SDorysprofte BaicIs P.yect Brochos. Aelke (8087)
# Thelscarf focvetue Wistapons by Moraser (60996)
# Brice thry c by Bhmams Sleviss ar by Hicles LopipafPy Lad
#  ----
# iter 4200, loss: 52.710337
# ----
#  groltig
# Athe thaje and of Ledodola Watdenthashe Fau toy Hemetiho if at Vathe Cheite (6131)
# The Wnrildor bby Citha by Fechon ioper fola dichar Meng teolt ife o@ ot wind SThomistilald ensere Wmeler (69
#  ----
# iter 4300, loss: 52.335002
# ----
#  )
# Momnt an Op jAthiecmoru (8007)
# Mostoprithext (8089)
# A Dane Iufd Swibidtrarl by Jaskam (1156)
# A8chow Madyz, (104510)
# Tuon Pimlle by Aroky FigHoyce (1801)
# Arnasterby ò 金—cobenster (16299)
# Le,sentul th
#  ----
# iter 4400, loss: 51.959372
# ----
#   Sorinte Ro ant by Founs Fichs (66840)
# Ther invet by Roskin-(7659)
# Erintrm Hor Withu brothergy by J. Spathas Worewibme Fuetm's (80166)
# Bilns t. Ellped by Jare Worazer Fiste, Gmy
#
# Z Ptedurf Arde Lotkes
#  ----
# iter 4500, loss: 51.412767
# ----
#  Wicthin Carienl RoWisheis (60061)
# The Wowis (64906)
# The Ane Dicwied Castoral bbe Mutheut (143664)
# Srelsers Llonis by Mak, Algmill (20-G6Whwof Wists or Moukev a Fatherdyicte: s Boran by Ncaty Anth.ar B
#  ----
# iter 4600, loss: 51.241766
# ----
#  by tera of G. Sabedvonns (7964)
# The Momons Earleng of Jonc Ent (10280)
# The Snaz-(1956)
# Carcom Cearl Ang Jilk an, an C.arle by Jallo by Loliem Shost (7438)
# Montatier by G. Exthulle (8106)
# The Ramee Eyv
#  ----
# iter 4700, loss: 50.841088
# ----
#  6030)
# Beaxicle Moognveby if by Monems (63997)
# Foyt't anrle Morpthars an an; Org, ,ers (m
# T;ers Diche Hlo-t Am.epy ... .enobyPstant oy by Hoyve Aleszsmatuxl (114204)
# Nprme ulav lett by Winiil by Hoves
#  ----
# iter 4800, loss: 50.680914
# ----
#  awibe Twor's by Chae Tauis (7110)
# The Wolon (13084)
# A Ded Janeu (9164)
# The Ssedienver by Ceablatu by Tolian by Jone (1431)
# Kickentrany by Jare (19595)
# The Maskerece iogus (10195)
# The Roriew (119281)
# M
#  ----
# iter 4900, loss: 50.092767
# ----
#  wna Molé Sezas Wi!sulice of Jomes by Ghurk De Yugule Gienr (6240)
# ThnPon, mast Louks Slofs Sookdan. Grameas ind bNath venstima Wortos rome, , FFre Ctuttorom thoigren傳 by Jars Wodlantuu by Joruluster b
#  ----
# iter 5000, loss: 49.672843
# ----
#  翹傳ic Walpice Raretate (.
# Frils by Atprial (15021)
# The Pillenn (12156)
# Wolmar (g8521)
# The Eilhp taritjs Alcall Kam/me Eoris by Hols MayYtt Datouned Saorson (707)
# Minde Wilikonnl Bimatast by Farna Rorii
#  ----
# iter 5100, loss: 49.525142
# ----
#  enn by ArOlus by Aleastery by Rodearlas Cary by Wand (6252)
# The Woyne T. Grinle by Tamale Trim by M. Tomm Deol by Ve Homane ou Pibos by Pricl my Heala by 111coule by Crorids Hotol Joyis Doyte (7087)
# T
#  ----
# iter 5200, loss: 49.054690
# ----
#  590)
# Twemink Cam Tre; Meaze Sellilgan Shovithe Hicherg —rilt Stanl's Aft of Chorstoby o(794920)
# The NMoulerby Ceriat (15655)
# The Tary Aupe by Fask are bonthrimide Walsty Cary Amtutenter bof Wethar Gur
#  ----
# iter 5300, loss: 49.006040
# ----
#  e Lutit (7622)
# The Be, of Frichaxt Fiechl or Sthitlan Coyd  A Megverlni (8914))
# Aerle by Frict of Ly Maute by thing am Momy an. Am Thaen/me by Oraves by Ctiof Somr Tuencnouce: by Thay Wolict: Mayle by
#  ----
# iter 5400, loss: 48.594740
# ----
#  ri翹ned (66096)
# C:dinhayae Vepth of textencom mur (11406)
# JOnsila fithu tet Wagerilles Yewr cole@s by Ale by Michen Tiett fuo (121312)The ine (6905)
# The Lopl trat oy ren by Vies by Hichath pmethe A t y
#  ----
# iter 5500, loss: 48.468223
# ----
#  Fyycran (14669)
# Cheacy by File by TiliWoby Capmon by Tomanl Soon A Le Frilceu 'f Pusteon Souliivang Aft by Wapkence (61511)
# The Trertee (11203)
# The Grilsy (
# 750)
# Hoy luather by Campe ind Af Wilspess F
#  ----
# iter 5600, loss: 48.064234
# ----
#  es the Gharict of Sthiviaster Serthas Sona, of (6530)
# Thuo by Doze (7113)
# Wiind Ha-vest Gofscom Sdiat by 30 .. Matëentanda by Narles Dickerlisis fe ttorow (6546)
# Wistas of tide: Sonane of ther (6135)
#
#  ----
# iter 5700, loss: 47.617934
# ----
#  (20674)
# Sichrast (11352)
# Slllsats of Wophalane of Cheg; SThonylos Oer Giges a zacoy (14172)
# Sheingerr Popmans Gare y Laalaven by Hearacce Sacding Griec (13378)
# Oas by Walyes by He Leld And by YoSVath
#  ----
# iter 5800, loss: 47.589049
# ----
#  s by Ricker (7601)
# Amasores ol Phimes Geuteyuinar Vanl She:ngsathrelunzs Woiches (887)
# The Dytster (7650)
# Wilt: y Vilzin by Lry Chos of Molicthi by Looxiom as by Warmanel by Wilt: erto Gr San by W. Cl
#  ----
# iter 5900, loss: 47.214505
# ----
#  09692)
# The byzand PargItan by Anteve IloD Cardilg a-dict/om tar Rote finhe Cinoueth A Pictus ot the Mrvopshan bby Eak Stakina by Aren P. Mome Dolle (880-186)
# The Smate Dorné Fry Pranan (623208)
# Weathe
#  ----
# iter 6000, loss: 47.199067
# ----
#   gulk, outote, iantur Poinc Hodprof Maver, Earichan by Thansomevonc oo-tes (13286)
# TLid Cons of tlise Dicho by Momasome by HhaskorKar, asre (9163)
#  Napoucd : Hool Irick by Coracut (9143)
# Thol by Homau
#  ----
# iter 6100, loss: 46.784213
# ----
#  g,utans af Alilouus bepht felues (6533)
# The ane ar veritthe iuad by Gilitts arispheus ouge toyten
#
# ralilzan oras on
# Tiethent piséa ext ofas, ahe Sen-ideistire by T. Twhanen derhd be Ld ReViston Gay i
#  ----
# iter 6200, loss: 46.530901
# ----
#  73553)
# Dy couvanletertuwisc by Frathoy Advimnk Coulane (1558)
# A He Ezaghboysdy Coule Hovesllestes (64243)
# Pralethan (12086)
# Tho Yidoldos Molon Wr SMowvopid Dofdos oinaisof Ad
# Matel Grranebychouce Lot
#  ----
# iter 6300, loss: 46.341431
# ----
#  verle Jomles by Chril Me Sickl of Worlilgictve yous of Taces (7348)
# Le Pilmer (7657)
# The Stiok Coltty (6991)
# The Aducule by Vattm an (7655)
# Ofer (6550)
# AcctesrlanG of Me by Gronvery bergmanre: Eséy by
#  ----
# iter 6400, loss: 45.922495
# ----
#  dard are Pudsear iader (6089)
# A Slols oby Chars cetiv (56931)
# Fratery an Carkel-Dels byoNals Hicheld (173900)
# Thy Shals Na th Sloviese by Jond Aariles Chas or —sone by Tlenjkerd SMomelle Pyor Pig the
#  ----
# iter 6500, loss: 45.891825
# ----
#  y o. thor(Scristrygulan Bonos by Granbyon Micé Darauu(Se Chang an Colot be MiOnt ou Fin (9992)
# LreJorich by Scyod Dickide (81377)
# The ostorblis Wihtritery On Dofom of AlcastoJaJn (8811)
# LsKan (9159)
# T
#  ----
# iter 6600, loss: 45.578635
# ----
#  he ITha f.. Grets/ by Thas. Gr by Fricos Duoke Lo Grlitien. Orgull thy 7f.. Fyophe Perargiel (12555)
# The Alrils Hetthisterthew Meul (1295)
# Moiss by Chorlanng, thxlas Cof trat, aus (9992)
# The Lorvict b
#  ----
# iter 6700, loss: 45.547083
# ----
#  rs by Elgies by Hegesuyas (213191)
# MaldateLiderves by Tharvenstsowu Cichof Taxdestmat (11306)
# The Kacerls Hoxpsens by Fines Sacy (111327)
# Rinllla (62583)
# The Dosgome by Grikens (70792)
# Urckelm Igrotue
#  ----
# iter 6800, loss: 45.135398
# ----
#  e Hestzexon TwescoedcIes y Chpl by Ricoulet (6921)
# The Mamn Moknes (6249)
# AnBlemic by Bhem Watp:m Yentdy Df Qhow by Augroricpha Diriody PenThanon Herke Phr anuthas Cor tha by Cowithuy n.
# CMelnas by St
#  ----
# iter 6900, loss: 44.770354
# ----
#   Horepeier randofd follas Mi7kJals Hornis (19450)
# The Dinkans Lauis by Homen ane (65522)
# oune Adve Fon Qor Esé fhilhens (19195)
# The Ardes Se Farak by Jiak Crome by Kiche Cravens Naigm Wanzad anglaid (
#  ----
# iter 7000, loss: 44.773802
# ----
#   Mortt (13366)
# Ansf by Lidliggrathor by Suon by Jacz by Nittomeand Hobstiman (1014)
# Olnteryby Hormas Soby Blepor Malle some (6987)
# Unctoti and: of Alcte by Wang A Chmate by Josea (7413)
# Seonte Prist s
#  ----
# iter 7100, loss: 44.428275
# ----
#   Jonel of Fintm by Joneow (..o3.../laf (74151)
# The Trom Leverte Chonter Gralsen -ritt (644630)
# The Anghxaneten lo Hink er Shofliza Dickerd Mans fenha blisale (15080)
# Liittee A Cictpephe Divent (16532!
#  ----
# iter 7200, loss: 44.434057
# ----
#  iczalme an urviane by Hellels by Cr Mr Moby by Jon Govanglal (73. Chonn on FrackeNd Karmve Pob Gagri Charpon by Hoyne by Elray of Kansë (1881)
# The Ophep by Fronos Doudest by Jomers of Ligeouecobny bev
#  ----
# iter 7300, loss: 44.132086
# ----
#  nte fn. mulilu fe d Chenes, Quaked (787)
# Mo8past : ou ses n.. Schottene by Fryvesw'sspy
#
#
#
#
# Phelliles y of aluilistisiy Sof thi by Ar.Giry .ert An-por Mel, ily yriHs fou/ter for the cromow Porllett b
#  ----
# iter 7400, loss: 44.047766
# ----
#  6)
# Chan Grarvem Woreame by Biltif Le Bent (147213)
# Thensmolle (19451)
# The P3y tsem (13286)
# Mandeigd Fatsiaf C.aricawisz Chry Marletiess (24206)
# The Thevalus yore Cayre wicof He Mard Crlane (15591)
# Mo
#  ----
# iter 7500, loss: 43.738991
# ----
#  r on Wardarintus of Ordorilt :y Orlecob Twor Mickand Dord De Bh Lidert Waist tha flost Wyoneureer, Hyonl ind Cuide Wilets by Thom: and as iicane Zoritle Pundor dl J. Roond ne's by Fone by Hocdle Qr'tt
#  ----
# iter 7600, loss: 43.400945
# ----
#  Wilot of Forknephre Wengon bon Aader (74002)
# TreeMuls Ltise (164632)
# Ermand Ede Ar Dickerdby Pucky Boigla (2potdezensow Griza (5410)
# The Pladll Willant (10.
#
# ThenI Pyogunk of Highaunesr Wardean G Shel
#  ----
# iter 7700, loss: 43.392513
# ----
#   (7070)
# Balnn by Rierd Wapddrn (6223)
# The Wigud Prictorang (1081)
# Herism (7020)
# Nanning Fapis (7422)
#
# The Pricated dy Christons of Mansel (7061)
# The Preste by (061)
# The Bromas A Puundln Wilasoe (7203)
#  ----
# iter 7800, loss: 43.199766
# ----
#  Fyotsto-10-145424)
# Dofce Ke Lindls the Perler-r Faruili aned c, Cmerlaves Gan, Wortmom Grassingus erthe Or Clueg at,e Kenrerase Cattos Dout on Thavel: (107654)
# Wibllas of Aichallict eosdhe -ueke tey Q
#  ----
# iter 7900, loss: 43.234397
# ----
#  (8268)
# Hinnales Tictuse by Homne by Rizelb by Cha@f (11463)
# Hi(7165)
# Ulitagn: Rpiens of Chorlestod Dopodes I1ddast Lor, siry by Dushes by Jacieln Jaykn (9295)
#
# 39612)
# Mandan (9635)
# lictstur Dond H. El
#  ----
# iter 8000, loss: 42.893294
# ----
#  na (6108)
# Cintlan lest (6848)
# Aunt Egttuyssown ord Shert ar ouleos by Jaxt L. Wom Rri6280)
# Ulint by ONg Likd (62o3)
# A Rocoral of Crap. (6207)
# Certhane Capm Wmols of sorism of Comat (62080)
# Coumawik by
#  ----
# iter 8100, loss: 42.697317
# ----
#  ofe Grima erl DisLens (1439203)
# The Pilhaibible Beoble Baralde Beomusteus (63751)
# Perthin Daven (A5ko
# Trar phopt Aysaor Levile Nartte Honst (59094)
# 金雲e Meltolisapiche Mongmals  fowlesma (19481)
# A Men/
#  ----
# iter 8200, loss: 42.597279
# ----
#   Shertickerd H. Narvethx Scvesken, of Bher, ald ; Or. Beris Hurdes Monopor by On. (6962)
# Nyllese by Kathoszery Dickens, laif (6322)
# An. indinar(7Q52)
# The ingouern of the (9907)
# The Tterthick A ciuve b
#  ----
# iter 8300, loss: 42.365308
# ----
#  vithf (l1 tle Luthens by tures yan. arlom Smariak Woletser(Sizaby by Moat of Kiak Hevlle Pariss Yence (2907)
# Ongsulaso; Linglas Dofe by Mews Gofs Fraigbless by Chaigegyby 3orompreous Prletrry Guter (1
#  ----
# iter 8400, loss: 42.384769
# ----
#  sr by Jaries (70203)
# The Foring Githelcona Bouwi of Lmonmas by ghadenn; (1717)
# The Arvomell (9514)
# FPede by Kawkonxthet C.orlety if Fuats, thrench ite Branobicton of Beigtbyscy thursy (6478)
# Adveuthom
#  ----
# iter 8500, loss: 42.186709
# ----
#  e by Fidderg by Elieke by Lof mase Dyot/liat:itte if uy alp are Lreit of te Ang, Hurest in Per Mant a digmiltmeth y by Aleg, adester Shotttill by Charibeegu/-14... phe traph anser V Falulcedm (61503)
#
#  ----
# iter 8600, loss: 42.168774
# ----
#  Carleste's Ditkenunapre Vicgo Ple of Tarictuan by Fan Twick Swolidvend by Cherl ou dian Concn A (2603)
# Nol Hickellaend Icplos by Andervea Deogserle therss of Meeradò —rifmore xilolis Goeselus (11920)
#
#  ----
# iter 8700, loss: 41.815543
# ----
#  Seedidnowolwet: Pryghon Scowicobedal Wilmilil on Gractoy Iun aohtpran S. F. Ad Algzel tur t (6280)
# The Wa,s of Mallod (6067)
# Thelle (662)
# WedenIGury by Andlcchange col ttowist by Bhasginalo (698)
# Bees
#  ----
# iter 8800, loss: 41.511267
# ----
#  by tradoD St,y icaldar an Twe
# Boran Sthis by Oe (12891)
# The Congeressi Blokg thom Ceure (1S74242)
# Licguie C Cimalisk Sheun; Conglas Mathiland (10761)
# The Erg arl by Hoad. Noodend Gad bof ousé by Momea
#  ----
# iter 8900, loss: 41.469374
# ----
#  The Wineë Fomed Karle berisoket Mattsarn. Mechit, IlesibI Huytaur of Prmafery Womanod P. Grant (g292)
# -)
# Woreth Mimet (6420)
# Thel Zaristos God Gristus: Intis by Miphariet chort: (Sctu Losttss by Brant
#  ----
# iter 9000, loss: 41.305817
# ----
#  s fhhprom Case Gristtar, Na j7ghizal og Fklivev ant ar, Oles Arctuexten
# Arvettur (144210)
# Witt Fincu (113!525)
# The BrojIuchens of Dister audl an6(61Vicpongenchuan (139924)
# Me Aive Lis Sghelopa-dvear (
#  ----
# iter 9100, loss: 41.273468
# ----
#   Hopchoul (1958)
# Napcot e Mopratr Loysm (85432)
# Alvent: (11114)
# The Grikeus Pr Hopransas (8929)
# A's and Sallila (7865)
# Shan by Ore; Lukeriburgont (1276)
# tryey Ehuken (1173)
# Grictim Kadisc of Fiskof Li
#  ----
# iter 9200, loss: 41.031639
# ----
#  stl Teld F: Empen Jumol andind Goh N. Frimpine Comdtrcby MreRuobe the  Complpike by Gpyet,es Tomas outte: ar Ilaza fofk mophore Fy Camomile by tle pywpayk W. Mrrithun ;orectin---173-; Or Wilphe//estoy
#  ----
# iter 9300, loss: 40.917037
# ----
#  ry by Cheales A Boikedlitk :iglmanl c Vdittharing Storeatr (16Noume by The ChofIs (71280)
# The Mosepralid (7013)
# Werdovens (11316)
# Lingatss (1083)
# The Kiafo (16036)
# The Wimer D O0cthepssy in Grillzanae
#  ----
# iter 9400, loss: 40.726893
# ----
#  htu ye of Wygrayles (6413)
# Ollcis boftt by Jalle by Mighis of Mhyon (opltten (6023)
# Danch by Alra Go Bethe Woan by M. wicthe teth, inats Fa of Grems (7313)
# Thaa Go Cara by Char Harith (961)
# Levenm by
#  ----
# iter 9500, loss: 40.396116
# ----
#  ces by Franl Stargemf oustame by Kany Warla diviriame by H.an by L. Sofistlman; af ertext (1446920)
# Arstorn Sher by DobBednane Ir Coune Cerkmond Joss (28864)
# Brerlevean an Cardeterice by Moby (11Wton
#  ----
# iter 9600, loss: 40.403350
# ----
#   Fartthinicheustous Wilop: Ethelobestyobbicguas Dicientreos Woyle by Jone Pervetod Arohungers of cené Domes (7086)
# Grelen. of Blen; Brasy Pidod Ivius Sarie by Bran by Jamy Wots of And Mimlomu by Hrasg
#  ----
# iter 9700, loss: 40.227597
# ----
#  MatherLfu sug, Mapethaw (96250)
# The Enmatte Cuer byay Yet/lak The Woless. thit !
# Mis. as -le A t, pon
# Cwam Re by Huth om Lonkde: and Ancooft of Len@ Aer mang annas Viwt byon (62070)
# The Pelliid Wilde:
#  ----
# iter 9800, loss: 40.228763
# ----
#  her (1999)
# Anne uule — Vaonerccenthing Scexk Shom Dury MomkanA (15036)
# Jalderca Searier (1801)
# The Touvapidave of Litext Frint (8353)
# Neltpay of Chellstoy Hoideun (8071)
# A Hol Pedernd Bangan and Ecqou
#  ----
# iter 9900, loss: 39.892695
# ----
#  uosé Shontë (6643)
# Cornd Distyen. ofes by Amd Ntsein by Aolkes be klicc Faros by Charlith Thethow by Robdicwectilic: Dickennr foram Sode Mortie Cor5k of Coupe Nohmstopitor Se of ol Twe Find Hof outtë
#  ----
# iter 10000, loss: 39.671513
# ----
#  ed navent (21250)
# A Ridiot tha Sicken (61890)
# The Cetie mence (12071)
# A Bercaus IMPelmdivier Talk dlovaons DooFe an Yesdoe Doipegobibip Chagles by FreNtle Elmanepes Howes End Wiyden (7907)
# Woulll' H o
#  ----
# iter 10100, loss: 39.682054
# ----
#  g wittha (7406)
# Fansthe : Od. rictex by Jerverek (7691)
# The Staler in Elian enariths Keato, ble Libertatt (7411)
# A Corighoe Mache Dacvarneroz Ptier igeis by Mankonteon Kangr fat en (6502)
# Linin (7377)
#  ----
# iter 10200, loss: 39.431253
# ----
#  Chran (W64362)
# T0ertlme (12817)
# Austlake Na Fevenr cok Tmem's (248216)
# Ttels ate W. Beriichas Carheis (136403)
# Tre Blake SthevCames Wojntind Alves Ariphicz an, anger by Josken, caang — Mon; Omr athim
#  ----
# iter 10300, loss: 39.501094
# ----
#  he Lorhs Wistt: Liberncaron  Souexod foutula for lod, Wilke (1107)
# Jandesuritolusthus (1147)
# The Roned by Thar bbecworvistlm Cwaminalue by Joses Grang byostss ofastes of Lrie; (6151)
# Scuentuennr's ofx
#  ----
# iter 10400, loss: 39.321941
# ----
#  Joul; witg yonethof in by Roon oice nmeinabyauler fto, Anthapy .
# rom textme yuratoy (8645)
# The texes by Orthrnot Cacpert/maneuttpy thast on, ce by Cerrat oreas Ahtsk (1376)
# C6Fitpiat Lot tre ple by th
#  ----
# iter 10500, loss: 39.349261
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 21
#      18   print ("---- \n %s \n ----" % (txt, ))
#      20 # forward seq_length characters through the net and fetch gradient
# ---> 21 loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      22 smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      23 if n % 100 == 0: print ("iter %d, loss: %f" % (n, smooth_loss)) # print progress
#
# Cell In[14], line 16, in lossFun(inputs, targets, hprev)
#      14 xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
#      15 xs[t][inputs[t]] = 1
# ---> 16 hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
#      17 ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
#      18 ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
